# %% [markdown]
# # Cybersec OpenEnv: GRPO training and evaluation
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/LonelyGuy-SE1/cybersec_env/blob/main/notebooks/cybersec_grpo.ipynb)
#
# **Training:** [TRL `GRPOTrainer`](https://huggingface.co/docs/trl/en/grpo_trainer) with [Unsloth](https://github.com/unslothai/unsloth) 4-bit QLoRA on `Qwen/Qwen2.5-1.5B-Instruct`, using this repo's OpenEnv package (`cybersec/`). Outer loops collect on-policy rows then run GRPO steps — same pattern as [OpenEnv + TRL](https://huggingface.co/docs/trl/en/openenv). Step rewards use the environment default (`cybersec/reward.py`).
#
# **Rewards:** `default_reward_funcs()` includes **`reward_batch_action_entropy`** (batch-level) plus per-prompt diversity so GRPO keeps variance when the model collapses to one action.
#
# **Headless:** From the repo root, `python scripts/train_cybersec_grpo.py --output-dir ./_artifacts` (GPU + Unsloth + TRL; see root README).
#
# **Config:** Tune the **`MODE`** dict in §1 for wall time vs. depth (`n_baseline_episodes`, `grpo_steps_per_outer_loop`, …). **`strict_canary`** gates post-training asserts.
#
# **Artifacts:** Colab → **`WORKDIR`** (default `/content/cybersec_workdir`). Local → **`_artifacts/`** (under the process cwd).

# %% [markdown]
# ## 0. Runtime, workdir, install (HF Space)
#
# On Colab/Kaggle, artifacts and the package snapshot live under `WORKDIR`.
# The next cells mirror the iter notebooks: **`os.chdir(WORKDIR)`** and **`cybersec_env_pkg` → `cybersec`**.

# %%
# Detect Colab / Kaggle / local. Artifacts + HF snapshot use WORKDIR on cloud kernels.
import os, sys
from pathlib import Path

if "google.colab" in sys.modules:
    RUNTIME = "colab"
    WORKDIR = Path("/content/cybersec_workdir")
elif Path("/kaggle/working").exists() or os.environ.get("KAGGLE_KERNEL_RUN_TYPE"):
    RUNTIME = "kaggle"
    WORKDIR = Path("/kaggle/working/cybersec_workdir")
else:
    RUNTIME = "local"
    WORKDIR = Path.cwd()

WORKDIR.mkdir(parents=True, exist_ok=True)
print(f"runtime: {RUNTIME}")
print(f"workdir: {WORKDIR}")
# Out:
# runtime: colab
# workdir: /content/cybersec_workdir

# %%
# %%capture
# Pull env from HF Space into WORKDIR, normalize folder name, editable install.
# Renaming cybersec_env_pkg -> cybersec before pip install -e keeps the path stable.
import os, sys, subprocess
from pathlib import Path

HF_SPACE_REPO_ID = "Lonelyguyse1/cybersec"
HF_SPACE_REVISION = "main"

if RUNTIME in {"colab", "kaggle"}:
    subprocess.run(
        [sys.executable, "-m", "pip", "install", "-q", "huggingface_hub>=0.24", "openenv-core>=0.2.2"],
        check=True,
    )
    from huggingface_hub import snapshot_download

    PKG_STAGE = WORKDIR / "cybersec_env_pkg"
    CYBERSEC_SRC = WORKDIR / "cybersec"
    PKG_STAGE.mkdir(parents=True, exist_ok=True)
    snapshot_download(
        repo_id=HF_SPACE_REPO_ID,
        repo_type="space",
        revision=HF_SPACE_REVISION,
        local_dir=str(PKG_STAGE),
        local_dir_use_symlinks=False,
    )
    if CYBERSEC_SRC.exists():
        install_root = CYBERSEC_SRC
    elif PKG_STAGE.exists():
        PKG_STAGE.rename(CYBERSEC_SRC)
        install_root = CYBERSEC_SRC
    else:
        raise RuntimeError("snapshot_download did not populate", PKG_STAGE)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-e", str(install_root)], check=True)
    # Space snapshots can lag GitHub; this notebook imports training helpers (e.g.
    # collect_grpo_rows_from_rollouts) that may not be on the Space yet.
    _gh = "git+https://github.com/LonelyGuy-SE1/cybersec_env.git@main#subdirectory=cybersec"
    subprocess.run(
        [sys.executable, "-m", "pip", "install", "-q", "--upgrade", _gh],
        check=True,
    )
else:
    install_root = Path("..").resolve() / "cybersec"
    print(f"local runtime; using in-tree package at {install_root}")

subprocess.run(
    [sys.executable, "-m", "pip", "install", "-q", "unsloth[cu121] @ git+https://github.com/unslothai/unsloth.git"],
    check=False,
)
subprocess.run(
    [sys.executable, "-m", "pip", "install", "-q", "--upgrade", "trl", "peft", "accelerate", "bitsandbytes"],
    check=False,
)
subprocess.run([sys.executable, "-m", "pip", "install", "-q", "matplotlib", "pandas"], check=False)

# %%
# Legacy Colab/Kaggle: same as `%cd cybersec_workdir` then `os.rename('cybersec_env_pkg','cybersec')`.
# If install already renamed, this is a no-op.
import os
from pathlib import Path

if RUNTIME in {"colab", "kaggle"}:
    # Same effect as Colab `%cd /content/cybersec_workdir` (path is `WORKDIR`).
    _ipy = globals().get("get_ipython", lambda: None)()
    if _ipy is not None:
        _ipy.run_line_magic("cd", str(WORKDIR))
    else:
        os.chdir(WORKDIR)
    print("cwd:", Path.cwd())
    if Path("cybersec_env_pkg").exists() and not Path("cybersec").exists():
        os.rename("cybersec_env_pkg", "cybersec")
        print("renamed cybersec_env_pkg -> cybersec")
# Out:
# /content/cybersec_workdir
# cwd: /content/cybersec_workdir

# %% [markdown]
# ## 1. Imports & config

# %%
from __future__ import annotations

# Iter-1's notebook output was buried under thousands of lines of identical
# `max_new_tokens / attention_mask` deprecation warnings. Silence the known
# noise *before* importing torch / transformers so the cell outputs are
# actually readable.
import warnings, logging
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning, module="transformers")
warnings.filterwarnings("ignore", category=DeprecationWarning)
logging.getLogger("transformers").setLevel(logging.ERROR)
logging.getLogger("accelerate").setLevel(logging.ERROR)
logging.getLogger("peft").setLevel(logging.ERROR)
logging.getLogger("huggingface_hub").setLevel(logging.ERROR)
logging.getLogger("trl").setLevel(logging.WARNING)
logging.getLogger("websockets").setLevel(logging.WARNING)

import base64
import copy
import gc
import json
import math
import os
import pickle
import random
import sys
import time
from pathlib import Path

import matplotlib
matplotlib.use("Agg") if "google.colab" not in sys.modules else None
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
from datasets import Dataset

from cybersec import (
    ActionType,
    CybersecAction,
    CybersecEnv,
    CybersecEnvironment,
    list_eval_scenarios,
    list_scenarios,
    list_train_scenarios,
)
from cybersec.baselines import (
    HeuristicPolicy,
    RandomPolicy,
    aggregate_results,
    run_episode,
)
from cybersec.training.rewards import (
    SYSTEM_PROMPT,
    collect_grpo_rows_from_rollouts,
    default_reward_funcs,
    parse_first_json_object,
    parsed_action,
    render_observation,
    restore_env,
    snapshot_env,
)

# ---------------------------------------------------------------------------
# Production MODE — tune for GPU memory and wall-clock.
# ---------------------------------------------------------------------------
MODE = {
    "strict_canary":           True,
    "n_baseline_episodes":     30,
    "n_dataset_seeds":         30,
    "max_dataset_rows":        1500,
    "on_policy_outer_loops":   2,
    "warmup_heuristic_outer0": True,
    "grpo_steps_per_outer_loop": 60,
    "grpo_num_train_epochs":   1,
    "grpo_num_generations":    8,
    "grpo_per_device_bs":      1,
    "grpo_grad_accum":         6,
    "grpo_logging_steps":      5,
    "grpo_save_steps":         50,
    "grpo_temperature":        1.4,
    "grpo_beta":               0.04,
    "grpo_learning_rate":      3e-5,
    "n_post_train_episodes":   30,
    "run_base_llm_eval":       True,
    "rollout_do_sample":       True,
    "rollout_temperature":     1.2,
    "rollout_top_p":           0.92,
    "eval_do_sample":          True,
    "eval_temperature":        0.85,
    "eval_top_p":              0.95,
    "use_remote_env":          False,
    "remote_env_url":          "https://lonelyguyse1-cybersec.hf.space",
}

MODE["grpo_max_steps_effective"] = (
    int(MODE["grpo_steps_per_outer_loop"]) * int(MODE["on_policy_outer_loops"])
)

if RUNTIME in ("colab", "kaggle"):
    ARTIFACTS = WORKDIR
else:
    ARTIFACTS = (Path.cwd() / "_artifacts").resolve()
ARTIFACTS.mkdir(parents=True, exist_ok=True)

ADAPTER_DIR        = ARTIFACTS / "qwen_cybersec_lora"
TRAIN_LOG          = ARTIFACTS / "training_log.json"
BASELINE_JSON      = ARTIFACTS / "baseline_metrics.json"
POST_JSON          = ARTIFACTS / "post_train_metrics.json"
HELDOUT_JSON       = ARTIFACTS / "heldout_metrics.json"
BASELINE_PLOT      = ARTIFACTS / "baseline_curves.png"
BEFORE_AFTER       = ARTIFACTS / "before_after_curves.png"
TRAIN_DIAGNOSTICS  = ARTIFACTS / "training_diagnostics.png"
SUMMARY_MD         = ARTIFACTS / "summary_table.md"
TRAJECTORY_JSON    = ARTIFACTS / "trajectory_dataset.jsonl"

MODEL_NAME      = "Qwen/Qwen2.5-1.5B-Instruct"
# GRPO applies left-truncation to `max_prompt_length` tokens; chat templates add overhead.
# Unsloth `max_seq_length` must be >= prompt + completion + template slack (TRL #3569).
MAX_PROMPT_LEN  = 2048
MAX_NEW_TOKENS  = 64
MAX_SEQ_LEN     = MAX_PROMPT_LEN + MAX_NEW_TOKENS + 256

TRAIN_SCENARIOS = list_train_scenarios()
HELDOUT_SCENARIOS = list_eval_scenarios()
ALL_SCENARIOS = list_scenarios()
SEEDS_BASELINE = list(range(MODE["n_baseline_episodes"]))
SEEDS_DATASET  = list(range(MODE["n_dataset_seeds"]))
SEEDS_POST     = list(range(MODE["n_post_train_episodes"]))

print("train scenarios:   ", TRAIN_SCENARIOS)
print("held-out scenarios:", HELDOUT_SCENARIOS)
print("MODE:")
print(json.dumps(MODE, indent=2))
if not os.environ.get("HF_TOKEN") and not os.environ.get("HUGGINGFACE_HUB_TOKEN"):
    print("Tip: set HF_TOKEN or HUGGINGFACE_HUB_TOKEN (e.g. Colab secrets) to avoid hub auth warnings when pulling models.")

# --- run_manifest.json: torch/CUDA + effective batch; extend after dataset & training ---
_eff_bs = MODE["grpo_per_device_bs"] * MODE["grpo_grad_accum"]
RUN_MANIFEST = ARTIFACTS / "run_manifest.json"
_manifest = {
    "started_at_utc":        time.strftime("%Y-%m-%dT%H:%M:%SZ", time.gmtime()),
    "mode":                  MODE,
    "model_name":            MODEL_NAME,
    "max_prompt_len":        MAX_PROMPT_LEN,
    "max_new_tokens":        MAX_NEW_TOKENS,
    "torch_version":         torch.__version__,
    "cuda_available":        torch.cuda.is_available(),
    "cuda_version":          getattr(torch.version, "cuda", None),
    "device_name":           (torch.cuda.get_device_name(0) if torch.cuda.is_available() else None),
    "effective_optim_batch":  _eff_bs,
    "notes":                 "GRPO uses fp16 on GPU (bf16 False); 4-bit base via Unsloth.",
    "bf16":                  False,
    "fp16":                  bool(torch.cuda.is_available()),
}
RUN_MANIFEST.write_text(json.dumps(_manifest, indent=2, default=str))
print("--- run_manifest (partial) ---")
print("  device:", _manifest["device_name"], "| fp16:", _manifest["fp16"], "| eff. batch (acc):", _eff_bs)
print("wrote", RUN_MANIFEST)
# Out:
# train scenarios:    ['supply_chain_token_drift', 'federated_identity_takeover', 'insider_repo_pivot']
# held-out scenarios: ['cloud_metadata_ssrf']
# MODE:
# {
#   "strict_canary": true,
#   "n_baseline_episodes": 30,
#   "n_dataset_seeds": 30,
#   "max_dataset_rows": 1500,
#   "on_policy_outer_loops": 2,
#   "warmup_heuristic_outer0": true,
#   "grpo_steps_per_outer_loop": 60,
#   "grpo_num_train_epochs": 1,
#   "grpo_num_generations": 8,
#   "grpo_per_device_bs": 1,
#   "grpo_grad_accum": 6,
#   "grpo_logging_steps": 5,
#   "grpo_save_steps": 50,
#   "grpo_temperature": 1.4,
#   "grpo_beta": 0.04,
#   "grpo_learning_rate": 3e-05,
#   "n_post_train_episodes": 30,
#   "run_base_llm_eval": true,
#   "rollout_do_sample": true,
#   "rollout_temperature": 1.2,
#   "rollout_top_p": 0.92,
#   "eval_do_sample": true,
#   "eval_temperature": 0.85,
#   "eval_top_p": 0.95,
#   "use_remote_env": false,
#   "remote_env_url": "https://lonelyguyse1-cybersec.hf.space",
#   "grpo_max_steps_effective": 120
# }
# Tip: set HF_TOKEN or HUGGINGFACE_HUB_TOKEN (e.g. Colab secrets) to avoid hub auth warnings when pulling models.
# --- run_manifest (partial) ---
#   device: Tesla T4 | fp16: True | eff. batch (acc): 6
# wrote /content/cybersec_workdir/run_manifest.json

# %% [markdown]
# ## 2. Baseline: Random vs Heuristic (train + held-out scenarios)

# %%
# Local CybersecEnvironment for fast in-kernel rollouts. We optionally
# repeat the baseline against the deployed HF Space below as a separate
# optional remote OpenEnv check (§2a).
env = CybersecEnvironment()
baseline_runs = {}

t0 = time.time()
for sid in ALL_SCENARIOS:
    rand = [run_episode(env, RandomPolicy(seed=s), seed=s, scenario_id=sid) for s in SEEDS_BASELINE]
    heur = [run_episode(env, HeuristicPolicy(),    seed=s, scenario_id=sid) for s in SEEDS_BASELINE]
    baseline_runs[sid] = {"random": rand, "heuristic": heur}
    print(f"{sid:<32s}  random={aggregate_results(rand)['mean_return']:7.3f}"
          f"  heuristic={aggregate_results(heur)['mean_return']:7.3f}")
print(f"baseline elapsed: {time.time()-t0:.1f}s")
# Out:
# supply_chain_token_drift          random=  2.156  heuristic=  2.872
# federated_identity_takeover       random=  0.198  heuristic=  2.985
# insider_repo_pivot                random=  2.905  heuristic=  3.057
# cloud_metadata_ssrf               random=  1.723  heuristic=  3.048
# baseline elapsed: 0.2s

# %% [markdown]
# ### 2a. (Optional) Remote environment check
#
# If `MODE['use_remote_env']` is `True`, this cell runs **one** baseline
# episode of the heuristic policy against the deployed HF Space env. The
# purpose is to prove that the same package code, served over the OpenEnv
# WebSocket protocol, returns identical-shape observations -- not to repeat
# the full baseline against the network (which would be slow).

# %%
import asyncio

async def _remote_env_probe():
    base_url = MODE["remote_env_url"]
    print(f"connecting to remote env: {base_url}")
    async with CybersecEnv(base_url=base_url) as remote:
        result = await remote.reset(seed=0, scenario_id=TRAIN_SCENARIOS[0])
        steps = 0
        cumulative = 0.0
        while not result.done and steps < 80:
            policy = HeuristicPolicy()
            action = policy.act(result.observation)
            result = await remote.step(action)
            cumulative += float(result.reward or 0.0)
            steps += 1
        print(f"remote heuristic episode: steps={steps}  cumulative_reward={cumulative:.3f}")

if MODE["use_remote_env"]:
    try:
        asyncio.run(_remote_env_probe())
    except Exception as exc:
        print(f"remote environment check failed (continuing with local): {exc!r}")
else:
    print("remote environment check skipped (MODE['use_remote_env'] is False)")
# Out:
# remote environment check skipped (MODE['use_remote_env'] is False)

# %% [markdown]
# ### 2b. Persist baseline metrics + plot

# %%
def _padded_cumulative(curves, target_len):
    out = np.zeros((len(curves), target_len), dtype=float)
    for i, c in enumerate(curves):
        out[i, : len(c)] = c
        if len(c) < target_len:
            out[i, len(c):] = 0.0  # episode over, no more reward
    return np.cumsum(out, axis=1)

n_panels = len(ALL_SCENARIOS)
fig, axes = plt.subplots(1, n_panels, figsize=(5 * n_panels, 4), sharey=True)
if n_panels == 1:
    axes = [axes]
for ax, sid in zip(axes, ALL_SCENARIOS):
    cell = baseline_runs[sid]
    horizon = max(max(len(r.reward_curve) for r in cell['random']),
                  max(len(r.reward_curve) for r in cell['heuristic']))
    for label, color in [("random", "tab:gray"), ("heuristic", "tab:blue")]:
        cumr = _padded_cumulative([r.reward_curve for r in cell[label]], horizon)
        mean = cumr.mean(axis=0); std = cumr.std(axis=0)
        ax.plot(mean, label=label, color=color)
        ax.fill_between(np.arange(horizon), mean - std, mean + std, color=color, alpha=0.15)
    held_out_tag = "  (HELD-OUT)" if sid in HELDOUT_SCENARIOS else ""
    ax.set_title(sid + held_out_tag, fontsize=10); ax.set_xlabel("tick"); ax.axhline(0, color="k", lw=0.5)
axes[0].set_ylabel("cumulative reward"); axes[0].legend()
fig.suptitle(f"Cybersec OpenEnv baselines, n={MODE['n_baseline_episodes']}/scenario")
fig.tight_layout(); fig.savefig(BASELINE_PLOT, dpi=140); plt.show()

baseline_metrics = {
    sid: {p: aggregate_results(cell[p]) for p in ("random", "heuristic")}
    for sid, cell in baseline_runs.items()
}
baseline_metrics["_meta"] = {
    "n_episodes": MODE["n_baseline_episodes"],
    "train_scenarios": TRAIN_SCENARIOS,
    "heldout_scenarios": HELDOUT_SCENARIOS,
}
BASELINE_JSON.write_text(json.dumps(baseline_metrics, indent=2))
print("wrote", BASELINE_JSON)
# Out:
# wrote /content/cybersec_workdir/baseline_metrics.json

# %% [markdown]
# ### 2c. Full-horizon episode trace (heuristic, illustration)
#
# One episode: each row is a tick — **action** the policy took and a **short slice** of the text observation the model sees (from `render_observation`). This does not use the LLM; it shows the protocol. Trained-LLM trace is in §7c after eval.

# %%
def run_and_print_episode_trace(env, policy, seed: int, scenario_id: str, obs_preview: int = 220):
    """Print tick-by-tick: what the policy saw, action, step reward, cumulative."""
    if hasattr(policy, "reset"):
        policy.reset()
    obs = env.reset(seed=seed, scenario_id=scenario_id)
    cumulative = 0.0
    rows = []
    while not obs.done:
        seen = render_observation(obs)[:obs_preview].replace("\n", " ")
        action = policy.act(obs)
        nxt = env.step(action)
        step_r = float(nxt.reward or 0.0)
        cumulative += step_r
        rows.append({
            "tick_after": nxt.tick,
            "action": action.model_dump(),
            "step_reward": round(step_r, 4),
            "cumulative": round(cumulative, 4),
            "observation_preview": seen,
        })
        obs = nxt
    tr = pd.DataFrame(rows)
    print(tr.to_string(index=False))
    return tr

# `env` is created in the baseline cell above; reuse it here.
_ = run_and_print_episode_trace(env, HeuristicPolicy(), seed=0, scenario_id=TRAIN_SCENARIOS[0])
# Out:
#  tick_after                                                                                     action  step_reward  cumulative                                                                                                                                                                                                          observation_preview
#           1                      {'metadata': {}, 'action_type': 'ActionType.MONITOR', 'target': None}        0.000       0.000 tick=0/70  scenario=supply_chain_token_drift  attacker=aggressive isolated_assets=[] revoked_identities=[] blocked_egress=[] patched=[] confirmed_compromised=[] valid_targets={'assets': ['ci-runner-01', 'artifact-registr
#           2                      {'metadata': {}, 'action_type': 'ActionType.MONITOR', 'target': None}        0.000       0.000 tick=1/70  scenario=supply_chain_token_drift  attacker=aggressive isolated_assets=[] revoked_identities=[] blocked_egress=[] patched=[] confirmed_compromised=[] valid_targets={'assets': ['ci-runner-01', 'artifact-registr
#           3                      {'metadata': {}, 'action_type': 'ActionType.MONITOR', 'target': None}        0.000       0.000 tick=2/70  scenario=supply_chain_token_drift  attacker=aggressive isolated_assets=[] revoked_identities=[] blocked_egress=[] patched=[] confirmed_compromised=[] valid_targets={'assets': ['ci-runner-01', 'artifact-registr
#           4                      {'metadata': {}, 'action_type': 'ActionType.MONITOR', 'target': None}        0.000       0.000 tick=3/70  scenario=supply_chain_token_drift  attacker=aggressive isolated_assets=[] revoked_identities=[] blocked_egress=[] patched=[] confirmed_compromised=[] valid_targets={'assets': ['ci-runner-01', 'artifact-registr
#           5                      {'metadata': {}, 'action_type': 'ActionType.MONITOR', 'target': None}        0.000       0.000 tick=4/70  scenario=supply_chain_token_drift  attacker=aggressive isolated_assets=[] revoked_identities=[] blocked_egress=[] patched=[] confirmed_compromised=[] valid_targets={'assets': ['ci-runner-01', 'artifact-registr
#           6 {'metadata': {}, 'action_type': 'ActionType.ISOLATE_ASSET', 'target': 'artifact-registry'}        4.682       4.682 tick=5/70  scenario=supply_chain_token_drift  attacker=aggressive isolated_assets=[] revoked_identities=[] blocked_egress=[] patched=[] confirmed_compromised=[] valid_targets={'assets': ['ci-runner-01', 'artifact-registr

# %% [markdown]
# ## 3. Reward functions (nine independent signals)
#
# All reward functions live in `cybersec.training.rewards` so the notebook,
# the tests, and any future training script use the same definitions.

# %%
REWARD_FUNCS = default_reward_funcs()
REWARD_NAMES = [f.__name__ for f in REWARD_FUNCS]
print("reward components:")
for n in REWARD_NAMES:
    print(f"  - {n}")
# Out:
# reward components:
#   - reward_json_valid
#   - reward_schema_valid
#   - reward_target_in_valid_targets
#   - reward_no_redundant_containment
#   - reward_step_total
#   - reward_avoids_exfil_path
#   - reward_action_diversity
#   - reward_observation_aware
#   - reward_batch_action_entropy
#   - reward_evidence_containment

# %% [markdown]
# ## 4. Load Qwen2.5-1.5B with Unsloth (4-bit QLoRA)

# %%
from unsloth import FastLanguageModel


def _drop_gen_max_length(lm) -> None:
    """Causal LMs often ship `generation_config.max_length` (e.g. 32768). Calling
    `.generate(..., max_new_tokens=...)` merges that in and Transformers warns that
    both are set. Unset `max_length` so only `max_new_tokens` applies."""
    gen_cfg = getattr(lm, "generation_config", None)
    if gen_cfg is not None and getattr(gen_cfg, "max_length", None) is not None:
        gen_cfg.max_length = None


model, tokenizer = FastLanguageModel.from_pretrained(
    model_name=MODEL_NAME,
    max_seq_length=MAX_SEQ_LEN,
    dtype=None,
    load_in_4bit=True,
)
model = FastLanguageModel.get_peft_model(
    model,
    r=16,
    lora_alpha=32,
    lora_dropout=0.05,
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj",
                    "gate_proj", "up_proj", "down_proj"],
    bias="none",
    use_gradient_checkpointing="unsloth",
    random_state=0,
)
tokenizer.pad_token = tokenizer.pad_token or tokenizer.eos_token
_drop_gen_max_length(model)
model.print_trainable_parameters()

def to_chat_prompt(row):
    msgs = [
        {"role": "system", "content": row["system"]},
        {"role": "user",   "content": row["prompt"]},
    ]
    text = tokenizer.apply_chat_template(msgs, tokenize=False, add_generation_prompt=True)
    return {"prompt": text}
# Out:
# ==((====))==  Unsloth 2026.4.8: Fast Qwen2 patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# unsloth/qwen2.5-1.5b-instruct-unsloth-bnb-4bit does not have a padding token! Will use pad_token = <|PAD_TOKEN|>.
# trainable params: 18,464,768 || all params: 1,562,179,072 || trainable%: 1.1820

# %% [markdown]
# ## 5. Outer loop: collect rows → GRPO
#
# Each iteration builds a fresh `Dataset` via `collect_grpo_rows_from_rollouts` (`cybersec.training.rewards`): **loop 0** uses **HeuristicPolicy** when `warmup_heuristic_outer0` is true; later loops use the **current LLM** (on-policy rollouts). **Training scenarios only**; held-out scenarios are for evaluation. Rows are mapped with `to_chat_prompt` from §4 before `GRPOTrainer`.

# %%
from trl import GRPOConfig, GRPOTrainer


class RolloutLLMPolicy:
    """Rollout policy using the *training* model weights (updates each outer loop)."""

    name = "rollout-llm"

    def __init__(self, lm, tok, *, do_sample: bool, temperature: float, top_p: float):
        self._lm = lm
        self._tok = tok
        self._do_sample = do_sample
        self._temperature = temperature
        self._top_p = top_p

    def reset(self) -> None:
        pass

    def act(self, obs):
        self._lm.eval()
        msgs = [
            {"role": "system", "content": SYSTEM_PROMPT},
            {"role": "user",   "content": render_observation(obs)},
        ]
        text = self._tok.apply_chat_template(msgs, tokenize=False, add_generation_prompt=True)
        inputs = self._tok(text, return_tensors="pt").to(self._lm.device)
        gen_kw = dict(
            max_new_tokens=MAX_NEW_TOKENS,
            pad_token_id=self._tok.eos_token_id,
        )
        if self._do_sample:
            gen_kw["do_sample"] = True
            gen_kw["temperature"] = self._temperature
            gen_kw["top_p"] = self._top_p
        else:
            gen_kw["do_sample"] = False
        with torch.inference_mode():
            out = self._lm.generate(**inputs, **gen_kw)
        completion = self._tok.decode(
            out[0][inputs.input_ids.shape[1] :], skip_special_tokens=True
        )
        a = parsed_action(completion)
        return a or CybersecAction(action_type=ActionType.INVESTIGATE, target="INVALID_TARGET_SYNTAX")


_use_fp16 = bool(torch.cuda.is_available())
_combined_history: list = []
_global_step_offset: int = 0
_grpo_total_sec = 0.0
_outer_n = int(MODE["on_policy_outer_loops"])

for outer_i in range(_outer_n):
    use_h = outer_i == 0 and MODE.get("warmup_heuristic_outer0", True)
    tag = "heuristic_warmup" if use_h else "llm_on_policy"
    print(f"=== outer {outer_i + 1}/{_outer_n}  collect: {tag} ===")
    _t_collect0 = time.time()
    if use_h:
        _pol = HeuristicPolicy()
    else:
        _pol = RolloutLLMPolicy(
            model,
            tokenizer,
            do_sample=bool(MODE.get("rollout_do_sample", True)),
            temperature=float(MODE.get("rollout_temperature", 0.9)),
            top_p=float(MODE.get("rollout_top_p", 0.92)),
        )
    rows = collect_grpo_rows_from_rollouts(
        TRAIN_SCENARIOS,
        SEEDS_DATASET,
        _pol,
        max_rows=int(MODE["max_dataset_rows"]),
        shuffle_seed=outer_i + 7,
    )
    print(f"  collected {len(rows)} rows in {time.time() - _t_collect0:.1f}s")
    ds = Dataset.from_list(rows)
    ds_chat = ds.map(to_chat_prompt)
    print("  first chat prompt (trunc):", ds_chat[0]["prompt"][:400])

    _cfg = GRPOConfig(
        output_dir=str(ARTIFACTS / f"grpo_checkpoints_outer{outer_i}"),
        learning_rate=MODE["grpo_learning_rate"],
        per_device_train_batch_size=MODE["grpo_per_device_bs"],
        gradient_accumulation_steps=MODE["grpo_grad_accum"],
        max_completion_length=MAX_NEW_TOKENS,
        num_generations=MODE["grpo_num_generations"],
        num_train_epochs=MODE.get("grpo_num_train_epochs", 1),
        max_steps=int(MODE["grpo_steps_per_outer_loop"]),
        logging_steps=MODE["grpo_logging_steps"],
        save_steps=MODE["grpo_save_steps"],
        save_total_limit=1,
        bf16=False,
        fp16=_use_fp16,
        report_to=[],
        seed=outer_i,
        temperature=MODE["grpo_temperature"],
        beta=MODE["grpo_beta"],
    )
    print("  GRPO max_steps (this outer):", _cfg.max_steps, "num_generations:", _cfg.num_generations)

    trainer = GRPOTrainer(
        model=model,
        args=_cfg,
        train_dataset=ds_chat,
        processing_class=tokenizer,
        reward_funcs=REWARD_FUNCS,
    )
    _t1 = time.time()
    trainer.train()
    _loop_sec = time.time() - _t1
    _grpo_total_sec += _loop_sec
    _raw_hist = getattr(trainer.state, "log_history", []) or []
    for _row in _raw_hist:
        _r = dict(_row)
        _s = _r.get("step")
        if _s is not None:
            _r["global_step"] = _global_step_offset + int(_s)
        _r["outer_loop"] = outer_i
        _combined_history.append(_r)
    _global_step_offset += int(getattr(trainer.state, "global_step", 0) or 0)
    print(f"  GRPO outer {outer_i} elapsed: {_loop_sec:.1f}s")
    del trainer
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

print(f"=== all outers GRPO time: {_grpo_total_sec:.1f}s ===")
if RUN_MANIFEST.exists():
    _mf = json.loads(RUN_MANIFEST.read_text())
    _mf["grpo_train_elapsed_s"] = round(_grpo_total_sec, 2)
    _mf["on_policy_outer_loops"] = _outer_n
    _mf["training_phase_finished_utc"] = time.strftime(
        "%Y-%m-%dT%H:%M:%SZ", time.gmtime()
    )
    _mf["dataset_rows_last_outer"] = len(rows)
    RUN_MANIFEST.write_text(json.dumps(_mf, indent=2, default=str))
# Out:
# === outer 1/2  collect: heuristic_warmup ===
#   collected 1377 rows in 0.8s
# Map:   0%|          | 0/1377 [00:00<?, ? examples/s]
#   first chat prompt (trunc): <|im_start|>system
# You are an SRE-grade cyber-defender driving an OpenEnv environment.
# Reply with exactly one JSON object on one line of the form
# {"action_type": "...", "target": "..."}.
# action_type must be one of MONITOR, INVESTIGATE, ISOLATE_ASSET, REVOKE_IDENTITY, BLOCK_EGRESS, PATCH_ASSET.
# target must be omitted (or null) for MONITOR; otherwise it must come from valid_targets.<|im_end|>
# <|im_s
# Unsloth: We now expect `per_device_train_batch_size` * `gradient_accumulation_steps` * `world_size` to be a multiple of `num_generations`.
# We will change the batch size of 1 to the `num_generations` of 8
#   GRPO max_steps (this outer): 60 num_generations: 8
# Unsloth: Will smartly offload gradients to save VRAM!
# {'loss': '0.07503', 'grad_norm': '0.5696', 'learning_rate': '2e-05', 'num_tokens': '8.123e+04', 'completions/mean_length': '21.8', 'completions/min_length': '13.4', 'completions/max_length': '59.4', 'completions/clipped_ratio': '0.01667', 'completions/mean_terminated_length': '21.09', 'completions/min_terminated_length': '13.4', 'completions/max_terminated_length': '50.2', 'rewards/reward_json_valid/mean': '0.9708', 'rewards/reward_json_valid/std': '0.147', 'rewards/reward_schema_valid/mean': '0.7208', 'rewards/reward_schema_valid/std': '0.4501', 'rewards/reward_target_in_valid_targets/mean': '0.5875', 'rewards/reward_target_in_valid_targets/std': '0.4919', 'rewards/reward_no_redundant_containment/mean': '0.6854', 'rewards/reward_no_redundant_containment/std': '0.4488', 'rewards/reward_step_total/mean': '-0.1337', 'rewards/reward_step_total/std': '0.8407', 'rewards/reward_avoids_exfil_path/mean': '0.2333', 'rewards/reward_avoids_exfil_path/std': '0.2232', 'rewards/reward_action_diversity/mean': '0.5625', 'rewards/reward_action_diversity/std': '0.433', 'rewards/reward_observation_aware/mean': '0.4367', 'rewards/reward_observation_aware/std': '0.4604', 'rewards/reward_batch_action_entropy/mean': '1.168', 'rewards/reward_batch_action_entropy/std': '0.797', 'rewards/reward_evidence_containment/mean': '0.3667', 'rewards/reward_evidence_containment/std': '0.3559', 'reward': '5.598', 'reward_std': '3.76', 'frac_reward_zero_std': '0', 'completion_length': '21.8', 'kl': '0.00041', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '230.9', 'epoch': '0.02183'}
# {'loss': '0.03565', 'grad_norm': '0.4387', 'learning_rate': '2.833e-05', 'num_tokens': '1.618e+05', 'completions/mean_length': '22', 'completions/min_length': '14.2', 'completions/max_length': '47.6', 'completions/clipped_ratio': '0.004167', 'completions/mean_terminated_length': '21.82', 'completions/min_terminated_length': '14.2', 'completions/max_terminated_length': '42.8', 'rewards/reward_json_valid/mean': '0.9917', 'rewards/reward_json_valid/std': '0.05774', 'rewards/reward_schema_valid/mean': '0.9125', 'rewards/reward_schema_valid/std': '0.2753', 'rewards/reward_target_in_valid_targets/mean': '0.8125', 'rewards/reward_target_in_valid_targets/std': '0.3797', 'rewards/reward_no_redundant_containment/mean': '0.8771', 'rewards/reward_no_redundant_containment/std': '0.2949', 'rewards/reward_step_total/mean': '0.2446', 'rewards/reward_step_total/std': '0.9843', 'rewards/reward_avoids_exfil_path/mean': '0.3092', 'rewards/reward_avoids_exfil_path/std': '0.234', 'rewards/reward_action_diversity/mean': '0.4083', 'rewards/reward_action_diversity/std': '0.3492', 'rewards/reward_observation_aware/mean': '0.6379', 'rewards/reward_observation_aware/std': '0.3957', 'rewards/reward_batch_action_entropy/mean': '1.111', 'rewards/reward_batch_action_entropy/std': '0.6013', 'rewards/reward_evidence_containment/mean': '0.4583', 'rewards/reward_evidence_containment/std': '0.3725', 'reward': '6.763', 'reward_std': '2.409', 'frac_reward_zero_std': '0.03333', 'completion_length': '22', 'kl': '0.01859', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '52.98', 'epoch': '0.04367'}
# {'loss': '0.02433', 'grad_norm': '0.5036', 'learning_rate': '2.556e-05', 'num_tokens': '2.416e+05', 'completions/mean_length': '21.32', 'completions/min_length': '18.6', 'completions/max_length': '34.8', 'completions/clipped_ratio': '0.004167', 'completions/mean_terminated_length': '21.14', 'completions/min_terminated_length': '18.6', 'completions/max_terminated_length': '27', 'rewards/reward_json_valid/mean': '0.9875', 'rewards/reward_json_valid/std': '0.06926', 'rewards/reward_schema_valid/mean': '0.9708', 'rewards/reward_schema_valid/std': '0.147', 'rewards/reward_target_in_valid_targets/mean': '0.8958', 'rewards/reward_target_in_valid_targets/std': '0.2978', 'rewards/reward_no_redundant_containment/mean': '0.9333', 'rewards/reward_no_redundant_containment/std': '0.212', 'rewards/reward_step_total/mean': '0.228', 'rewards/reward_step_total/std': '0.9618', 'rewards/reward_avoids_exfil_path/mean': '0.4088', 'rewards/reward_avoids_exfil_path/std': '0.1831', 'rewards/reward_action_diversity/mean': '0.4208', 'rewards/reward_action_diversity/std': '0.3564', 'rewards/reward_observation_aware/mean': '0.7983', 'rewards/reward_observation_aware/std': '0.3623', 'rewards/reward_batch_action_entropy/mean': '1.111', 'rewards/reward_batch_action_entropy/std': '0.5265', 'rewards/reward_evidence_containment/mean': '0.635', 'rewards/reward_evidence_containment/std': '0.3013', 'reward': '7.39', 'reward_std': '1.715', 'frac_reward_zero_std': '0.06667', 'completion_length': '21.32', 'kl': '0.03415', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '44.45', 'epoch': '0.0655'}
# {'loss': '0.007676', 'grad_norm': '0.372', 'learning_rate': '2.278e-05', 'num_tokens': '3.291e+05', 'completions/mean_length': '20.7', 'completions/min_length': '17', 'completions/max_length': '38.6', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '20.7', 'completions/min_terminated_length': '17', 'completions/max_terminated_length': '38.6', 'rewards/reward_json_valid/mean': '0.9958', 'rewards/reward_json_valid/std': '0.02887', 'rewards/reward_schema_valid/mean': '0.975', 'rewards/reward_schema_valid/std': '0.09625', 'rewards/reward_target_in_valid_targets/mean': '0.9208', 'rewards/reward_target_in_valid_targets/std': '0.2668', 'rewards/reward_no_redundant_containment/mean': '0.95', 'rewards/reward_no_redundant_containment/std': '0.1631', 'rewards/reward_step_total/mean': '0.2491', 'rewards/reward_step_total/std': '0.9974', 'rewards/reward_avoids_exfil_path/mean': '0.4217', 'rewards/reward_avoids_exfil_path/std': '0.1529', 'rewards/reward_action_diversity/mean': '0.55', 'rewards/reward_action_diversity/std': '0.3403', 'rewards/reward_observation_aware/mean': '0.8292', 'rewards/reward_observation_aware/std': '0.3432', 'rewards/reward_batch_action_entropy/mean': '1.325', 'rewards/reward_batch_action_entropy/std': '0.5088', 'rewards/reward_evidence_containment/mean': '0.6467', 'rewards/reward_evidence_containment/std': '0.268', 'reward': '7.864', 'reward_std': '1.78', 'frac_reward_zero_std': '0', 'completion_length': '20.7', 'kl': '0.04363', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '96.72', 'epoch': '0.08734'}
# {'loss': '0.02004', 'grad_norm': '0.469', 'learning_rate': '2e-05', 'num_tokens': '4.096e+05', 'completions/mean_length': '20.72', 'completions/min_length': '18', 'completions/max_length': '39.6', 'completions/clipped_ratio': '0.008333', 'completions/mean_terminated_length': '20.36', 'completions/min_terminated_length': '18', 'completions/max_terminated_length': '28.2', 'rewards/reward_json_valid/mean': '1', 'rewards/reward_json_valid/std': '0', 'rewards/reward_schema_valid/mean': '0.9833', 'rewards/reward_schema_valid/std': '0.08078', 'rewards/reward_target_in_valid_targets/mean': '0.9333', 'rewards/reward_target_in_valid_targets/std': '0.2473', 'rewards/reward_no_redundant_containment/mean': '0.9792', 'rewards/reward_no_redundant_containment/std': '0.1096', 'rewards/reward_step_total/mean': '0.3872', 'rewards/reward_step_total/std': '0.9365', 'rewards/reward_avoids_exfil_path/mean': '0.3342', 'rewards/reward_avoids_exfil_path/std': '0.1938', 'rewards/reward_action_diversity/mean': '0.6417', 'rewards/reward_action_diversity/std': '0.3116', 'rewards/reward_observation_aware/mean': '0.7325', 'rewards/reward_observation_aware/std': '0.3543', 'rewards/reward_batch_action_entropy/mean': '1.456', 'rewards/reward_batch_action_entropy/std': '0.4231', 'rewards/reward_evidence_containment/mean': '0.545', 'rewards/reward_evidence_containment/std': '0.2903', 'reward': '7.993', 'reward_std': '1.529', 'frac_reward_zero_std': '0', 'completion_length': '20.72', 'kl': '0.04414', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '46.05', 'epoch': '0.1092'}
# {'loss': '0.004162', 'grad_norm': '0.3178', 'learning_rate': '1.722e-05', 'num_tokens': '4.95e+05', 'completions/mean_length': '19.99', 'completions/min_length': '17.2', 'completions/max_length': '22.8', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '19.99', 'completions/min_terminated_length': '17.2', 'completions/max_terminated_length': '22.8', 'rewards/reward_json_valid/mean': '0.9958', 'rewards/reward_json_valid/std': '0.02887', 'rewards/reward_schema_valid/mean': '0.9625', 'rewards/reward_schema_valid/std': '0.1406', 'rewards/reward_target_in_valid_targets/mean': '0.8958', 'rewards/reward_target_in_valid_targets/std': '0.2954', 'rewards/reward_no_redundant_containment/mean': '0.8875', 'rewards/reward_no_redundant_containment/std': '0.3026', 'rewards/reward_step_total/mean': '0.264', 'rewards/reward_step_total/std': '0.8405', 'rewards/reward_avoids_exfil_path/mean': '0.2896', 'rewards/reward_avoids_exfil_path/std': '0.2298', 'rewards/reward_action_diversity/mean': '0.6792', 'rewards/reward_action_diversity/std': '0.3465', 'rewards/reward_observation_aware/mean': '0.6342', 'rewards/reward_observation_aware/std': '0.4112', 'rewards/reward_batch_action_entropy/mean': '1.508', 'rewards/reward_batch_action_entropy/std': '0.4753', 'rewards/reward_evidence_containment/mean': '0.415', 'rewards/reward_evidence_containment/std': '0.3565', 'reward': '7.531', 'reward_std': '1.913', 'frac_reward_zero_std': '0.03333', 'completion_length': '19.99', 'kl': '0.0434', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '43.92', 'epoch': '0.131'}
# {'loss': '-0.00625', 'grad_norm': '0.4567', 'learning_rate': '1.444e-05', 'num_tokens': '5.742e+05', 'completions/mean_length': '19.95', 'completions/min_length': '16.4', 'completions/max_length': '23.8', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '19.95', 'completions/min_terminated_length': '16.4', 'completions/max_terminated_length': '23.8', 'rewards/reward_json_valid/mean': '0.9917', 'rewards/reward_json_valid/std': '0.05774', 'rewards/reward_schema_valid/mean': '0.9333', 'rewards/reward_schema_valid/std': '0.2443', 'rewards/reward_target_in_valid_targets/mean': '0.8875', 'rewards/reward_target_in_valid_targets/std': '0.3123', 'rewards/reward_no_redundant_containment/mean': '0.9167', 'rewards/reward_no_redundant_containment/std': '0.2615', 'rewards/reward_step_total/mean': '0.2881', 'rewards/reward_step_total/std': '0.9106', 'rewards/reward_avoids_exfil_path/mean': '0.3658', 'rewards/reward_avoids_exfil_path/std': '0.193', 'rewards/reward_action_diversity/mean': '0.6667', 'rewards/reward_action_diversity/std': '0.3418', 'rewards/reward_observation_aware/mean': '0.7158', 'rewards/reward_observation_aware/std': '0.4211', 'rewards/reward_batch_action_entropy/mean': '1.465', 'rewards/reward_batch_action_entropy/std': '0.509', 'rewards/reward_evidence_containment/mean': '0.5817', 'rewards/reward_evidence_containment/std': '0.3122', 'reward': '7.812', 'reward_std': '2.37', 'frac_reward_zero_std': '0', 'completion_length': '19.95', 'kl': '0.05207', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '39.19', 'epoch': '0.1528'}
# {'loss': '0.01521', 'grad_norm': '0.5004', 'learning_rate': '1.167e-05', 'num_tokens': '6.551e+05', 'completions/mean_length': '20.47', 'completions/min_length': '17.2', 'completions/max_length': '35.4', 'completions/clipped_ratio': '0.004167', 'completions/mean_terminated_length': '20.28', 'completions/min_terminated_length': '17.2', 'completions/max_terminated_length': '27.4', 'rewards/reward_json_valid/mean': '1', 'rewards/reward_json_valid/std': '0', 'rewards/reward_schema_valid/mean': '0.9625', 'rewards/reward_schema_valid/std': '0.1904', 'rewards/reward_target_in_valid_targets/mean': '0.925', 'rewards/reward_target_in_valid_targets/std': '0.2571', 'rewards/reward_no_redundant_containment/mean': '0.9083', 'rewards/reward_no_redundant_containment/std': '0.2764', 'rewards/reward_step_total/mean': '0.3441', 'rewards/reward_step_total/std': '0.9564', 'rewards/reward_avoids_exfil_path/mean': '0.3429', 'rewards/reward_avoids_exfil_path/std': '0.215', 'rewards/reward_action_diversity/mean': '0.6583', 'rewards/reward_action_diversity/std': '0.3454', 'rewards/reward_observation_aware/mean': '0.7492', 'rewards/reward_observation_aware/std': '0.3713', 'rewards/reward_batch_action_entropy/mean': '1.436', 'rewards/reward_batch_action_entropy/std': '0.473', 'rewards/reward_evidence_containment/mean': '0.5233', 'rewards/reward_evidence_containment/std': '0.34', 'reward': '7.85', 'reward_std': '2.052', 'frac_reward_zero_std': '0', 'completion_length': '20.47', 'kl': '0.06824', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '46.85', 'epoch': '0.1747'}
# {'loss': '-0.00298', 'grad_norm': '0.3369', 'learning_rate': '8.889e-06', 'num_tokens': '7.435e+05', 'completions/mean_length': '20.15', 'completions/min_length': '16.6', 'completions/max_length': '31', 'completions/clipped_ratio': '0.004167', 'completions/mean_terminated_length': '19.97', 'completions/min_terminated_length': '16.6', 'completions/max_terminated_length': '22.6', 'rewards/reward_json_valid/mean': '0.9958', 'rewards/reward_json_valid/std': '0.02887', 'rewards/reward_schema_valid/mean': '0.9708', 'rewards/reward_schema_valid/std': '0.1297', 'rewards/reward_target_in_valid_targets/mean': '0.925', 'rewards/reward_target_in_valid_targets/std': '0.2609', 'rewards/reward_no_redundant_containment/mean': '0.9417', 'rewards/reward_no_redundant_containment/std': '0.2288', 'rewards/reward_step_total/mean': '0.4071', 'rewards/reward_step_total/std': '0.9382', 'rewards/reward_avoids_exfil_path/mean': '0.3775', 'rewards/reward_avoids_exfil_path/std': '0.1862', 'rewards/reward_action_diversity/mean': '0.65', 'rewards/reward_action_diversity/std': '0.3329', 'rewards/reward_observation_aware/mean': '0.7967', 'rewards/reward_observation_aware/std': '0.3595', 'rewards/reward_batch_action_entropy/mean': '1.44', 'rewards/reward_batch_action_entropy/std': '0.4821', 'rewards/reward_evidence_containment/mean': '0.5867', 'rewards/reward_evidence_containment/std': '0.3091', 'reward': '8.091', 'reward_std': '1.845', 'frac_reward_zero_std': '0', 'completion_length': '20.15', 'kl': '0.09383', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '47.6', 'epoch': '0.1965'}
# {'loss': '-0.01108', 'grad_norm': '0.3883', 'learning_rate': '6.111e-06', 'num_tokens': '8.251e+05', 'completions/mean_length': '20.34', 'completions/min_length': '15.4', 'completions/max_length': '39.8', 'completions/clipped_ratio': '0.008333', 'completions/mean_terminated_length': '19.97', 'completions/min_terminated_length': '15.4', 'completions/max_terminated_length': '23.8', 'rewards/reward_json_valid/mean': '1', 'rewards/reward_json_valid/std': '0', 'rewards/reward_schema_valid/mean': '0.9875', 'rewards/reward_schema_valid/std': '0.06926', 'rewards/reward_target_in_valid_targets/mean': '0.925', 'rewards/reward_target_in_valid_targets/std': '0.2628', 'rewards/reward_no_redundant_containment/mean': '0.9812', 'rewards/reward_no_redundant_containment/std': '0.1126', 'rewards/reward_step_total/mean': '0.3822', 'rewards/reward_step_total/std': '0.8808', 'rewards/reward_avoids_exfil_path/mean': '0.3733', 'rewards/reward_avoids_exfil_path/std': '0.1912', 'rewards/reward_action_diversity/mean': '0.7', 'rewards/reward_action_diversity/std': '0.3266', 'rewards/reward_observation_aware/mean': '0.7533', 'rewards/reward_observation_aware/std': '0.3933', 'rewards/reward_batch_action_entropy/mean': '1.485', 'rewards/reward_batch_action_entropy/std': '0.4688', 'rewards/reward_evidence_containment/mean': '0.6033', 'rewards/reward_evidence_containment/std': '0.2993', 'reward': '8.191', 'reward_std': '1.476', 'frac_reward_zero_std': '0', 'completion_length': '20.34', 'kl': '0.06596', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '49.54', 'epoch': '0.2183'}
# {'loss': '-0.002616', 'grad_norm': '0.2092', 'learning_rate': '3.333e-06', 'num_tokens': '9.059e+05', 'completions/mean_length': '20.05', 'completions/min_length': '17.2', 'completions/max_length': '22.8', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '20.05', 'completions/min_terminated_length': '17.2', 'completions/max_terminated_length': '22.8', 'rewards/reward_json_valid/mean': '1', 'rewards/reward_json_valid/std': '0', 'rewards/reward_schema_valid/mean': '0.9833', 'rewards/reward_schema_valid/std': '0.09812', 'rewards/reward_target_in_valid_targets/mean': '0.9583', 'rewards/reward_target_in_valid_targets/std': '0.199', 'rewards/reward_no_redundant_containment/mean': '0.9458', 'rewards/reward_no_redundant_containment/std': '0.2203', 'rewards/reward_step_total/mean': '0.4493', 'rewards/reward_step_total/std': '0.9677', 'rewards/reward_avoids_exfil_path/mean': '0.3833', 'rewards/reward_avoids_exfil_path/std': '0.1867', 'rewards/reward_action_diversity/mean': '0.6417', 'rewards/reward_action_diversity/std': '0.3222', 'rewards/reward_observation_aware/mean': '0.7975', 'rewards/reward_observation_aware/std': '0.347', 'rewards/reward_batch_action_entropy/mean': '1.456', 'rewards/reward_batch_action_entropy/std': '0.4334', 'rewards/reward_evidence_containment/mean': '0.5967', 'rewards/reward_evidence_containment/std': '0.3258', 'reward': '8.212', 'reward_std': '1.665', 'frac_reward_zero_std': '0', 'completion_length': '20.05', 'kl': '0.07969', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '40.79', 'epoch': '0.2402'}
# {'loss': '0.02381', 'grad_norm': '0.4088', 'learning_rate': '5.556e-07', 'num_tokens': '9.903e+05', 'completions/mean_length': '20.44', 'completions/min_length': '17.4', 'completions/max_length': '33.6', 'completions/clipped_ratio': '0.004167', 'completions/mean_terminated_length': '20.25', 'completions/min_terminated_length': '17.4', 'completions/max_terminated_length': '25.2', 'rewards/reward_json_valid/mean': '1', 'rewards/reward_json_valid/std': '0', 'rewards/reward_schema_valid/mean': '0.9917', 'rewards/reward_schema_valid/std': '0.05774', 'rewards/reward_target_in_valid_targets/mean': '0.9292', 'rewards/reward_target_in_valid_targets/std': '0.2542', 'rewards/reward_no_redundant_containment/mean': '0.975', 'rewards/reward_no_redundant_containment/std': '0.1385', 'rewards/reward_step_total/mean': '0.4059', 'rewards/reward_step_total/std': '0.9194', 'rewards/reward_avoids_exfil_path/mean': '0.3871', 'rewards/reward_avoids_exfil_path/std': '0.1844', 'rewards/reward_action_diversity/mean': '0.675', 'rewards/reward_action_diversity/std': '0.3279', 'rewards/reward_observation_aware/mean': '0.7975', 'rewards/reward_observation_aware/std': '0.353', 'rewards/reward_batch_action_entropy/mean': '1.502', 'rewards/reward_batch_action_entropy/std': '0.4494', 'rewards/reward_evidence_containment/mean': '0.6183', 'rewards/reward_evidence_containment/std': '0.2962', 'reward': '8.282', 'reward_std': '1.374', 'frac_reward_zero_std': '0', 'completion_length': '20.44', 'kl': '0.04202', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '48.46', 'epoch': '0.262'}
# {'train_runtime': '3965', 'train_samples_per_second': '0.726', 'train_steps_per_second': '0.015', 'train_loss': '0.01525', 'epoch': '0.262'}
#   GRPO outer 0 elapsed: 3970.7s
# === outer 2/2  collect: llm_on_policy ===
#   collected 689 rows in 880.0s
# Map:   0%|          | 0/689 [00:00<?, ? examples/s]
#   first chat prompt (trunc): <|im_start|>system
# You are an SRE-grade cyber-defender driving an OpenEnv environment.
# Reply with exactly one JSON object on one line of the form
# {"action_type": "...", "target": "..."}.
# action_type must be one of MONITOR, INVESTIGATE, ISOLATE_ASSET, REVOKE_IDENTITY, BLOCK_EGRESS, PATCH_ASSET.
# target must be omitted (or null) for MONITOR; otherwise it must come from valid_targets.<|im_end|>
# <|im_s
# Unsloth: We now expect `per_device_train_batch_size` * `gradient_accumulation_steps` * `world_size` to be a multiple of `num_generations`.
# We will change the batch size of 1 to the `num_generations` of 8
#   GRPO max_steps (this outer): 60 num_generations: 8
# Unsloth: Will smartly offload gradients to save VRAM!
# {'loss': '0.01208', 'grad_norm': '0.3614', 'learning_rate': '2e-05', 'num_tokens': '7.465e+04', 'completions/mean_length': '19.82', 'completions/min_length': '16', 'completions/max_length': '22', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '19.82', 'completions/min_terminated_length': '16', 'completions/max_terminated_length': '22', 'rewards/reward_json_valid/mean': '0.9917', 'rewards/reward_json_valid/std': '0.05774', 'rewards/reward_schema_valid/mean': '0.9708', 'rewards/reward_schema_valid/std': '0.1251', 'rewards/reward_target_in_valid_targets/mean': '0.9292', 'rewards/reward_target_in_valid_targets/std': '0.2454', 'rewards/reward_no_redundant_containment/mean': '0.5042', 'rewards/reward_no_redundant_containment/std': '0.5026', 'rewards/reward_step_total/mean': '-0.04431', 'rewards/reward_step_total/std': '0.5836', 'rewards/reward_avoids_exfil_path/mean': '0.2792', 'rewards/reward_avoids_exfil_path/std': '0.2406', 'rewards/reward_action_diversity/mean': '0.5583', 'rewards/reward_action_diversity/std': '0.3483', 'rewards/reward_observation_aware/mean': '0.6558', 'rewards/reward_observation_aware/std': '0.3747', 'rewards/reward_batch_action_entropy/mean': '1.357', 'rewards/reward_batch_action_entropy/std': '0.4738', 'rewards/reward_evidence_containment/mean': '0.1583', 'rewards/reward_evidence_containment/std': '0.2934', 'reward': '6.36', 'reward_std': '1.722', 'frac_reward_zero_std': '0', 'completion_length': '19.82', 'kl': '0.07634', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '39.32', 'epoch': '0.04386'}
# {'loss': '-0.01058', 'grad_norm': '0.3086', 'learning_rate': '2.833e-05', 'num_tokens': '1.523e+05', 'completions/mean_length': '19.34', 'completions/min_length': '16.6', 'completions/max_length': '25.6', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '19.34', 'completions/min_terminated_length': '16.6', 'completions/max_terminated_length': '25.6', 'rewards/reward_json_valid/mean': '0.9958', 'rewards/reward_json_valid/std': '0.02887', 'rewards/reward_schema_valid/mean': '0.9625', 'rewards/reward_schema_valid/std': '0.1655', 'rewards/reward_target_in_valid_targets/mean': '0.8958', 'rewards/reward_target_in_valid_targets/std': '0.2852', 'rewards/reward_no_redundant_containment/mean': '0.8083', 'rewards/reward_no_redundant_containment/std': '0.3837', 'rewards/reward_step_total/mean': '0.21', 'rewards/reward_step_total/std': '0.8603', 'rewards/reward_avoids_exfil_path/mean': '0.2625', 'rewards/reward_avoids_exfil_path/std': '0.227', 'rewards/reward_action_diversity/mean': '0.7292', 'rewards/reward_action_diversity/std': '0.319', 'rewards/reward_observation_aware/mean': '0.595', 'rewards/reward_observation_aware/std': '0.3941', 'rewards/reward_batch_action_entropy/mean': '1.552', 'rewards/reward_batch_action_entropy/std': '0.4598', 'rewards/reward_evidence_containment/mean': '0.2967', 'rewards/reward_evidence_containment/std': '0.3554', 'reward': '7.307', 'reward_std': '1.948', 'frac_reward_zero_std': '0', 'completion_length': '19.34', 'kl': '0.08834', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '88.27', 'epoch': '0.08772'}
# {'loss': '-0.003428', 'grad_norm': '0.4208', 'learning_rate': '2.556e-05', 'num_tokens': '2.21e+05', 'completions/mean_length': '19.38', 'completions/min_length': '16.6', 'completions/max_length': '22.8', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '19.38', 'completions/min_terminated_length': '16.6', 'completions/max_terminated_length': '22.8', 'rewards/reward_json_valid/mean': '1', 'rewards/reward_json_valid/std': '0', 'rewards/reward_schema_valid/mean': '0.9583', 'rewards/reward_schema_valid/std': '0.196', 'rewards/reward_target_in_valid_targets/mean': '0.8792', 'rewards/reward_target_in_valid_targets/std': '0.3122', 'rewards/reward_no_redundant_containment/mean': '0.9375', 'rewards/reward_no_redundant_containment/std': '0.243', 'rewards/reward_step_total/mean': '0.2928', 'rewards/reward_step_total/std': '0.9963', 'rewards/reward_avoids_exfil_path/mean': '0.1538', 'rewards/reward_avoids_exfil_path/std': '0.2026', 'rewards/reward_action_diversity/mean': '0.8042', 'rewards/reward_action_diversity/std': '0.2998', 'rewards/reward_observation_aware/mean': '0.4517', 'rewards/reward_observation_aware/std': '0.3844', 'rewards/reward_batch_action_entropy/mean': '1.653', 'rewards/reward_batch_action_entropy/std': '0.4477', 'rewards/reward_evidence_containment/mean': '0.2617', 'rewards/reward_evidence_containment/std': '0.3272', 'reward': '7.392', 'reward_std': '1.931', 'frac_reward_zero_std': '0', 'completion_length': '19.38', 'kl': '0.1423', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '34.81', 'epoch': '0.1316'}
# {'loss': '0.01345', 'grad_norm': '0.3616', 'learning_rate': '2.278e-05', 'num_tokens': '2.934e+05', 'completions/mean_length': '19.77', 'completions/min_length': '16.8', 'completions/max_length': '30.4', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '19.77', 'completions/min_terminated_length': '16.8', 'completions/max_terminated_length': '30.4', 'rewards/reward_json_valid/mean': '1', 'rewards/reward_json_valid/std': '0', 'rewards/reward_schema_valid/mean': '0.975', 'rewards/reward_schema_valid/std': '0.1559', 'rewards/reward_target_in_valid_targets/mean': '0.8708', 'rewards/reward_target_in_valid_targets/std': '0.3338', 'rewards/reward_no_redundant_containment/mean': '0.9667', 'rewards/reward_no_redundant_containment/std': '0.1759', 'rewards/reward_step_total/mean': '0.4515', 'rewards/reward_step_total/std': '1.019', 'rewards/reward_avoids_exfil_path/mean': '0.1704', 'rewards/reward_avoids_exfil_path/std': '0.2104', 'rewards/reward_action_diversity/mean': '0.825', 'rewards/reward_action_diversity/std': '0.2758', 'rewards/reward_observation_aware/mean': '0.4017', 'rewards/reward_observation_aware/std': '0.3976', 'rewards/reward_batch_action_entropy/mean': '1.672', 'rewards/reward_batch_action_entropy/std': '0.4129', 'rewards/reward_evidence_containment/mean': '0.2933', 'rewards/reward_evidence_containment/std': '0.3325', 'reward': '7.626', 'reward_std': '1.776', 'frac_reward_zero_std': '0', 'completion_length': '19.77', 'kl': '0.1187', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '41.92', 'epoch': '0.1754'}
# {'loss': '-0.004834', 'grad_norm': '0.3605', 'learning_rate': '2e-05', 'num_tokens': '3.694e+05', 'completions/mean_length': '19.82', 'completions/min_length': '15.8', 'completions/max_length': '24.4', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '19.82', 'completions/min_terminated_length': '15.8', 'completions/max_terminated_length': '24.4', 'rewards/reward_json_valid/mean': '0.9958', 'rewards/reward_json_valid/std': '0.02887', 'rewards/reward_schema_valid/mean': '0.9708', 'rewards/reward_schema_valid/std': '0.15', 'rewards/reward_target_in_valid_targets/mean': '0.9083', 'rewards/reward_target_in_valid_targets/std': '0.29', 'rewards/reward_no_redundant_containment/mean': '0.95', 'rewards/reward_no_redundant_containment/std': '0.1885', 'rewards/reward_step_total/mean': '0.3117', 'rewards/reward_step_total/std': '0.9009', 'rewards/reward_avoids_exfil_path/mean': '0.1883', 'rewards/reward_avoids_exfil_path/std': '0.2285', 'rewards/reward_action_diversity/mean': '0.7542', 'rewards/reward_action_diversity/std': '0.3058', 'rewards/reward_observation_aware/mean': '0.47', 'rewards/reward_observation_aware/std': '0.4156', 'rewards/reward_batch_action_entropy/mean': '1.591', 'rewards/reward_batch_action_entropy/std': '0.4294', 'rewards/reward_evidence_containment/mean': '0.305', 'rewards/reward_evidence_containment/std': '0.3637', 'reward': '7.445', 'reward_std': '1.725', 'frac_reward_zero_std': '0', 'completion_length': '19.82', 'kl': '0.1108', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '41.52', 'epoch': '0.2193'}
# {'loss': '0.008262', 'grad_norm': '0.7651', 'learning_rate': '1.722e-05', 'num_tokens': '4.482e+05', 'completions/mean_length': '20.72', 'completions/min_length': '16.2', 'completions/max_length': '45', 'completions/clipped_ratio': '0.008333', 'completions/mean_terminated_length': '20.35', 'completions/min_terminated_length': '16.2', 'completions/max_terminated_length': '29.4', 'rewards/reward_json_valid/mean': '0.9958', 'rewards/reward_json_valid/std': '0.02887', 'rewards/reward_schema_valid/mean': '0.9667', 'rewards/reward_schema_valid/std': '0.1366', 'rewards/reward_target_in_valid_targets/mean': '0.9042', 'rewards/reward_target_in_valid_targets/std': '0.2847', 'rewards/reward_no_redundant_containment/mean': '0.9375', 'rewards/reward_no_redundant_containment/std': '0.2294', 'rewards/reward_step_total/mean': '0.2269', 'rewards/reward_step_total/std': '0.9395', 'rewards/reward_avoids_exfil_path/mean': '0.2125', 'rewards/reward_avoids_exfil_path/std': '0.2154', 'rewards/reward_action_diversity/mean': '0.775', 'rewards/reward_action_diversity/std': '0.2909', 'rewards/reward_observation_aware/mean': '0.5817', 'rewards/reward_observation_aware/std': '0.4111', 'rewards/reward_batch_action_entropy/mean': '1.549', 'rewards/reward_batch_action_entropy/std': '0.4294', 'rewards/reward_evidence_containment/mean': '0.3783', 'rewards/reward_evidence_containment/std': '0.3504', 'reward': '7.527', 'reward_std': '1.828', 'frac_reward_zero_std': '0', 'completion_length': '20.72', 'kl': '0.3153', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '49.45', 'epoch': '0.2632'}
# {'loss': '0.02232', 'grad_norm': '0.5026', 'learning_rate': '1.444e-05', 'num_tokens': '5.239e+05', 'completions/mean_length': '21.57', 'completions/min_length': '17.2', 'completions/max_length': '54', 'completions/clipped_ratio': '0.01667', 'completions/mean_terminated_length': '20.85', 'completions/min_terminated_length': '17.2', 'completions/max_terminated_length': '34.2', 'rewards/reward_json_valid/mean': '0.9917', 'rewards/reward_json_valid/std': '0.05774', 'rewards/reward_schema_valid/mean': '0.975', 'rewards/reward_schema_valid/std': '0.1385', 'rewards/reward_target_in_valid_targets/mean': '0.9458', 'rewards/reward_target_in_valid_targets/std': '0.2203', 'rewards/reward_no_redundant_containment/mean': '0.95', 'rewards/reward_no_redundant_containment/std': '0.2174', 'rewards/reward_step_total/mean': '0.3536', 'rewards/reward_step_total/std': '1.007', 'rewards/reward_avoids_exfil_path/mean': '0.1887', 'rewards/reward_avoids_exfil_path/std': '0.2297', 'rewards/reward_action_diversity/mean': '0.7208', 'rewards/reward_action_diversity/std': '0.3232', 'rewards/reward_observation_aware/mean': '0.4308', 'rewards/reward_observation_aware/std': '0.4195', 'rewards/reward_batch_action_entropy/mean': '1.531', 'rewards/reward_batch_action_entropy/std': '0.4677', 'rewards/reward_evidence_containment/mean': '0.3417', 'rewards/reward_evidence_containment/std': '0.3724', 'reward': '7.429', 'reward_std': '1.581', 'frac_reward_zero_std': '0', 'completion_length': '21.57', 'kl': '0.1315', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '53.34', 'epoch': '0.307'}
# {'loss': '0.06843', 'grad_norm': '0.6883', 'learning_rate': '1.167e-05', 'num_tokens': '5.973e+05', 'completions/mean_length': '22.52', 'completions/min_length': '17.2', 'completions/max_length': '63', 'completions/clipped_ratio': '0.025', 'completions/mean_terminated_length': '21.45', 'completions/min_terminated_length': '17.2', 'completions/max_terminated_length': '35.6', 'rewards/reward_json_valid/mean': '0.975', 'rewards/reward_json_valid/std': '0.1559', 'rewards/reward_schema_valid/mean': '0.9542', 'rewards/reward_schema_valid/std': '0.2003', 'rewards/reward_target_in_valid_targets/mean': '0.9083', 'rewards/reward_target_in_valid_targets/std': '0.2799', 'rewards/reward_no_redundant_containment/mean': '0.9083', 'rewards/reward_no_redundant_containment/std': '0.2684', 'rewards/reward_step_total/mean': '0.449', 'rewards/reward_step_total/std': '1.098', 'rewards/reward_avoids_exfil_path/mean': '0.1446', 'rewards/reward_avoids_exfil_path/std': '0.208', 'rewards/reward_action_diversity/mean': '0.7125', 'rewards/reward_action_diversity/std': '0.3252', 'rewards/reward_observation_aware/mean': '0.4233', 'rewards/reward_observation_aware/std': '0.3747', 'rewards/reward_batch_action_entropy/mean': '1.459', 'rewards/reward_batch_action_entropy/std': '0.498', 'rewards/reward_evidence_containment/mean': '0.2417', 'rewards/reward_evidence_containment/std': '0.3341', 'reward': '7.175', 'reward_std': '1.92', 'frac_reward_zero_std': '0', 'completion_length': '22.52', 'kl': '0.134', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '59.19', 'epoch': '0.3509'}
# {'loss': '0.006693', 'grad_norm': '0.6895', 'learning_rate': '8.889e-06', 'num_tokens': '6.732e+05', 'completions/mean_length': '21.44', 'completions/min_length': '16.4', 'completions/max_length': '49.4', 'completions/clipped_ratio': '0.0125', 'completions/mean_terminated_length': '20.9', 'completions/min_terminated_length': '16.4', 'completions/max_terminated_length': '27.8', 'rewards/reward_json_valid/mean': '0.9958', 'rewards/reward_json_valid/std': '0.02887', 'rewards/reward_schema_valid/mean': '0.9667', 'rewards/reward_schema_valid/std': '0.1759', 'rewards/reward_target_in_valid_targets/mean': '0.9208', 'rewards/reward_target_in_valid_targets/std': '0.2679', 'rewards/reward_no_redundant_containment/mean': '0.9542', 'rewards/reward_no_redundant_containment/std': '0.2105', 'rewards/reward_step_total/mean': '0.5462', 'rewards/reward_step_total/std': '1.095', 'rewards/reward_avoids_exfil_path/mean': '0.2613', 'rewards/reward_avoids_exfil_path/std': '0.2352', 'rewards/reward_action_diversity/mean': '0.6625', 'rewards/reward_action_diversity/std': '0.3124', 'rewards/reward_observation_aware/mean': '0.5375', 'rewards/reward_observation_aware/std': '0.4494', 'rewards/reward_batch_action_entropy/mean': '1.51', 'rewards/reward_batch_action_entropy/std': '0.4594', 'rewards/reward_evidence_containment/mean': '0.49', 'rewards/reward_evidence_containment/std': '0.3546', 'reward': '7.845', 'reward_std': '1.85', 'frac_reward_zero_std': '0', 'completion_length': '21.44', 'kl': '0.1221', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '50.84', 'epoch': '0.3947'}
# {'loss': '0.01047', 'grad_norm': '0.3762', 'learning_rate': '6.111e-06', 'num_tokens': '7.453e+05', 'completions/mean_length': '22.21', 'completions/min_length': '18.2', 'completions/max_length': '50.2', 'completions/clipped_ratio': '0.008333', 'completions/mean_terminated_length': '21.86', 'completions/min_terminated_length': '18.2', 'completions/max_terminated_length': '38.6', 'rewards/reward_json_valid/mean': '0.9958', 'rewards/reward_json_valid/std': '0.02887', 'rewards/reward_schema_valid/mean': '0.9875', 'rewards/reward_schema_valid/std': '0.0866', 'rewards/reward_target_in_valid_targets/mean': '0.9583', 'rewards/reward_target_in_valid_targets/std': '0.199', 'rewards/reward_no_redundant_containment/mean': '0.9667', 'rewards/reward_no_redundant_containment/std': '0.154', 'rewards/reward_step_total/mean': '0.7251', 'rewards/reward_step_total/std': '1.074', 'rewards/reward_avoids_exfil_path/mean': '0.2058', 'rewards/reward_avoids_exfil_path/std': '0.217', 'rewards/reward_action_diversity/mean': '0.6708', 'rewards/reward_action_diversity/std': '0.3176', 'rewards/reward_observation_aware/mean': '0.4667', 'rewards/reward_observation_aware/std': '0.3981', 'rewards/reward_batch_action_entropy/mean': '1.466', 'rewards/reward_batch_action_entropy/std': '0.429', 'rewards/reward_evidence_containment/mean': '0.3367', 'rewards/reward_evidence_containment/std': '0.3514', 'reward': '7.78', 'reward_std': '1.403', 'frac_reward_zero_std': '0', 'completion_length': '22.21', 'kl': '0.1225', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '50.95', 'epoch': '0.4386'}
# {'loss': '0.01248', 'grad_norm': '0.512', 'learning_rate': '3.333e-06', 'num_tokens': '8.231e+05', 'completions/mean_length': '22.1', 'completions/min_length': '17.4', 'completions/max_length': '45', 'completions/clipped_ratio': '0.008333', 'completions/mean_terminated_length': '21.75', 'completions/min_terminated_length': '17.4', 'completions/max_terminated_length': '37.8', 'rewards/reward_json_valid/mean': '0.9833', 'rewards/reward_json_valid/std': '0.07779', 'rewards/reward_schema_valid/mean': '0.9583', 'rewards/reward_schema_valid/std': '0.174', 'rewards/reward_target_in_valid_targets/mean': '0.9125', 'rewards/reward_target_in_valid_targets/std': '0.2783', 'rewards/reward_no_redundant_containment/mean': '0.9083', 'rewards/reward_no_redundant_containment/std': '0.2822', 'rewards/reward_step_total/mean': '0.5273', 'rewards/reward_step_total/std': '1.091', 'rewards/reward_avoids_exfil_path/mean': '0.2942', 'rewards/reward_avoids_exfil_path/std': '0.217', 'rewards/reward_action_diversity/mean': '0.6167', 'rewards/reward_action_diversity/std': '0.3414', 'rewards/reward_observation_aware/mean': '0.56', 'rewards/reward_observation_aware/std': '0.4505', 'rewards/reward_batch_action_entropy/mean': '1.384', 'rewards/reward_batch_action_entropy/std': '0.4866', 'rewards/reward_evidence_containment/mean': '0.465', 'rewards/reward_evidence_containment/std': '0.3548', 'reward': '7.609', 'reward_std': '1.994', 'frac_reward_zero_std': '0', 'completion_length': '22.1', 'kl': '0.1326', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '49.82', 'epoch': '0.4825'}
# {'loss': '0.00897', 'grad_norm': '0.4747', 'learning_rate': '5.556e-07', 'num_tokens': '9.033e+05', 'completions/mean_length': '23.05', 'completions/min_length': '17.2', 'completions/max_length': '56', 'completions/clipped_ratio': '0.0125', 'completions/mean_terminated_length': '22.53', 'completions/min_terminated_length': '17.2', 'completions/max_terminated_length': '39', 'rewards/reward_json_valid/mean': '0.9875', 'rewards/reward_json_valid/std': '0.06926', 'rewards/reward_schema_valid/mean': '0.9583', 'rewards/reward_schema_valid/std': '0.196', 'rewards/reward_target_in_valid_targets/mean': '0.9333', 'rewards/reward_target_in_valid_targets/std': '0.2443', 'rewards/reward_no_redundant_containment/mean': '0.9417', 'rewards/reward_no_redundant_containment/std': '0.2345', 'rewards/reward_step_total/mean': '0.6661', 'rewards/reward_step_total/std': '1.055', 'rewards/reward_avoids_exfil_path/mean': '0.27', 'rewards/reward_avoids_exfil_path/std': '0.1711', 'rewards/reward_action_diversity/mean': '0.5792', 'rewards/reward_action_diversity/std': '0.3316', 'rewards/reward_observation_aware/mean': '0.4908', 'rewards/reward_observation_aware/std': '0.414', 'rewards/reward_batch_action_entropy/mean': '1.307', 'rewards/reward_batch_action_entropy/std': '0.503', 'rewards/reward_evidence_containment/mean': '0.4433', 'rewards/reward_evidence_containment/std': '0.2665', 'reward': '7.577', 'reward_std': '1.93', 'frac_reward_zero_std': '0', 'completion_length': '23.05', 'kl': '0.135', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '54.25', 'epoch': '0.5263'}
# {'train_runtime': '3095', 'train_samples_per_second': '0.931', 'train_steps_per_second': '0.019', 'train_loss': '0.01203', 'epoch': '0.5263'}
#   GRPO outer 1 elapsed: 3104.2s
# === all outers GRPO time: 7074.9s ===

# %% [markdown]
# ## 6. Save adapter + training log

# %%
ADAPTER_DIR.mkdir(exist_ok=True)
model.save_pretrained(str(ADAPTER_DIR))
tokenizer.save_pretrained(str(ADAPTER_DIR))

history = _combined_history
TRAIN_LOG.write_text(json.dumps({
    "reward_names": REWARD_NAMES,
    "history": history,
    "model_name": MODEL_NAME,
    "mode": MODE,
}, indent=2))
print("saved adapter to", ADAPTER_DIR)
print("wrote", TRAIN_LOG, "with", len(history), "log rows")
if RUN_MANIFEST.exists():
    _mf = json.loads(RUN_MANIFEST.read_text())
    _mf["training_log_path"] = str(TRAIN_LOG)
    _mf["training_log_rows"] = len(history)
    if history and isinstance(history[-1], dict):
        _mf["last_log_step"] = history[-1].get("global_step", history[-1].get("step"))
    RUN_MANIFEST.write_text(json.dumps(_mf, indent=2, default=str))
# Out:
# saved adapter to /content/cybersec_workdir/qwen_cybersec_lora
# wrote /content/cybersec_workdir/training_log.json with 26 log rows

# %% [markdown]
# ### 6a. Training diagnostics: KL, loss, per-component reward
#
# Iter-1 had no KL/entropy plots, so we couldn't see the policy collapsing
# toward a single canned plan even though the cumulative reward kept
# climbing. These plots are the early-warning system: if KL is rising fast
# and `reward_action_diversity` plateaus near `1/num_generations`, the
# policy is mode-collapsing and you should stop and adjust.

# %%
log = json.loads(TRAIN_LOG.read_text()) if TRAIN_LOG.exists() else {"history": []}
hist = log.get("history") or []

if not hist:
    print("no training log rows -- did GRPO train?")
else:
    df_log = pd.DataFrame(hist)
    _xcol = "global_step" if "global_step" in df_log.columns else "step"
    if _xcol not in df_log.columns:
        df_log[_xcol] = range(len(df_log))
        _xcol = "step"

    base_cols = ["loss", "kl", "reward", "completion_length", "grad_norm"]
    component_cols = [c for c in df_log.columns
                      if c.startswith("rewards/") or c in REWARD_NAMES
                      or any(c.endswith(name) for name in REWARD_NAMES)]

    fig, axes = plt.subplots(1, 3, figsize=(15, 4))

    # panel 1: loss + kl
    for col, color in [("loss", "tab:blue"), ("kl", "tab:red")]:
        if col in df_log.columns and df_log[col].notna().any():
            axes[0].plot(df_log[_xcol], df_log[col], label=col, color=color)
    axes[0].set_title("loss / KL"); axes[0].set_xlabel(_xcol); axes[0].legend()

    # panel 2: total reward + completion length
    if "reward" in df_log.columns and df_log["reward"].notna().any():
        axes[1].plot(df_log[_xcol], df_log["reward"], label="reward", color="tab:green")
    if "completion_length" in df_log.columns and df_log["completion_length"].notna().any():
        ax2 = axes[1].twinx()
        ax2.plot(df_log[_xcol], df_log["completion_length"], label="completion_length",
                 color="tab:purple", linestyle="--")
        ax2.set_ylabel("completion_length", color="tab:purple")
    axes[1].set_title("total reward + completion length"); axes[1].set_xlabel(_xcol)
    axes[1].legend(loc="upper left")

    # panel 3: per-reward-component breakdown
    if component_cols:
        for col in component_cols:
            if df_log[col].notna().any():
                short = col.split("/")[-1].replace("reward_", "")
                axes[2].plot(df_log[_xcol], df_log[col], label=short, alpha=0.85)
        axes[2].set_title("reward components per step")
        axes[2].set_xlabel(_xcol)
        axes[2].legend(fontsize=7, ncol=2, loc="best")
    else:
        axes[2].set_title("(no per-component reward columns in log)")

    fig.tight_layout(); fig.savefig(TRAIN_DIAGNOSTICS, dpi=140); plt.show()
    print("wrote", TRAIN_DIAGNOSTICS)
# Out:
# wrote /content/cybersec_workdir/training_diagnostics.png

# %% [markdown]
# ## 7. Evaluate base LLM vs trained policy
#
# 1. **Base** `Qwen2.5-1.5B-Instruct` (no LoRA, same 4-bit load) on **all** scenarios
#    — set `MODE["run_base_llm_eval"] = False` to skip and save time.
# 2. **Trained adapter** — reload through **Unsloth** so LoRA + fused attention match training.
#
# Use `FastLanguageModel.from_pretrained` on `ADAPTER_DIR` after freeing VRAM from the base run.

# %%
from unsloth import FastLanguageModel

# Free training-only buffers if the kernel still has them.
for _name in ("model", "trainer"):
    if _name in globals():
        del globals()[_name]
gc.collect()
torch.cuda.empty_cache()

base_runs: dict = {}
if MODE.get("run_base_llm_eval", True):
    base_eval_model, base_tokenizer = FastLanguageModel.from_pretrained(
        model_name=MODEL_NAME,
        max_seq_length=MAX_SEQ_LEN,
        dtype=None,
        load_in_4bit=True,
    )
    base_tokenizer.pad_token = base_tokenizer.pad_token or base_tokenizer.eos_token
    FastLanguageModel.for_inference(base_eval_model)
    _drop_gen_max_length(base_eval_model)

    @torch.inference_mode()
    def _base_llm_act(obs):
        msgs = [
            {"role": "system", "content": SYSTEM_PROMPT},
            {"role": "user",   "content": render_observation(obs)},
        ]
        text = base_tokenizer.apply_chat_template(msgs, tokenize=False, add_generation_prompt=True)
        inputs = base_tokenizer(text, return_tensors="pt").to(base_eval_model.device)
        out = base_eval_model.generate(
            **inputs,
            max_new_tokens=MAX_NEW_TOKENS,
            do_sample=bool(MODE.get("eval_do_sample", True)),
            temperature=float(MODE.get("eval_temperature", 0.85)),
            top_p=float(MODE.get("eval_top_p", 0.95)),
            pad_token_id=base_tokenizer.eos_token_id,
        )
        completion = base_tokenizer.decode(
            out[0][inputs.input_ids.shape[1]:], skip_special_tokens=True
        )
        a = parsed_action(completion)
        _base_llm_act._last_was_fallback = a is None
        return a or CybersecAction(action_type=ActionType.INVESTIGATE, target="INVALID_TARGET_SYNTAX")

    class BaseLLMPolicy:
        name = "qwen-1.5b-base"
        last_act_was_fallback = False
        def reset(self):
            self.last_act_was_fallback = False
        def act(self, obs):
            act_out = _base_llm_act(obs)
            self.last_act_was_fallback = bool(getattr(_base_llm_act, "_last_was_fallback", False))
            return act_out

    t0 = time.time()
    for sid in ALL_SCENARIOS:
        runs = [run_episode(env, BaseLLMPolicy(), seed=s, scenario_id=sid) for s in SEEDS_POST]
        base_runs[sid] = runs
        agg = aggregate_results(runs)
        std = float(np.std([r.cumulative_reward for r in runs]))
        print(f"[base-llm] {sid:<32s}  mean={agg['mean_return']:7.3f}  std={std:.3f}  "
              f"mon_fb={agg.get('monitor_fallback_rate', 0):.3f}")
    print(f"base-llm eval elapsed: {time.time()-t0:.1f}s")

    del base_eval_model, base_tokenizer
    gc.collect()
    torch.cuda.empty_cache()
else:
    print("skipping base-LLM eval (MODE['run_base_llm_eval'] is False)")

eval_model, eval_tokenizer = FastLanguageModel.from_pretrained(
    model_name=str(ADAPTER_DIR),
    max_seq_length=MAX_SEQ_LEN,
    dtype=None,
    load_in_4bit=True,
)
eval_tokenizer.pad_token = eval_tokenizer.pad_token or eval_tokenizer.eos_token
FastLanguageModel.for_inference(eval_model)
_drop_gen_max_length(eval_model)
print("loaded trained adapter via Unsloth for evaluation")
# Out:
# ==((====))==  Unsloth 2026.4.8: Fast Qwen2 patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# unsloth/qwen2.5-1.5b-instruct-unsloth-bnb-4bit does not have a padding token! Will use pad_token = <|PAD_TOKEN|>.
# [base-llm] supply_chain_token_drift          mean=  5.832  std=0.791  mon_fb=0.204
# [base-llm] federated_identity_takeover       mean=  1.498  std=0.924  mon_fb=0.111
# [base-llm] insider_repo_pivot                mean=  4.627  std=2.130  mon_fb=0.105
# [base-llm] cloud_metadata_ssrf               mean=  4.912  std=1.575  mon_fb=0.133
# base-llm eval elapsed: 357.5s
# ==((====))==  Unsloth 2026.4.8: Fast Qwen2 patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# unsloth/qwen2.5-1.5b-instruct-unsloth-bnb-4bit does not have a padding token! Will use pad_token = <|PAD_TOKEN|>.
# loaded trained adapter via Unsloth for evaluation

# %%
@torch.inference_mode()
def llm_act(obs):
    msgs = [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user",   "content": render_observation(obs)},
    ]
    text = eval_tokenizer.apply_chat_template(msgs, tokenize=False, add_generation_prompt=True)
    inputs = eval_tokenizer(text, return_tensors="pt").to(eval_model.device)
    out = eval_model.generate(
        **inputs,
        max_new_tokens=MAX_NEW_TOKENS,
        do_sample=bool(MODE.get("eval_do_sample", True)),
        temperature=float(MODE.get("eval_temperature", 0.85)),
        top_p=float(MODE.get("eval_top_p", 0.95)),
        pad_token_id=eval_tokenizer.eos_token_id,
    )
    completion = eval_tokenizer.decode(
        out[0][inputs.input_ids.shape[1]:], skip_special_tokens=True
    )
    a = parsed_action(completion)
    llm_act._last_was_fallback = a is None
    return a or CybersecAction(action_type=ActionType.INVESTIGATE, target="INVALID_TARGET_SYNTAX")

class TrainedLLMPolicy:
    name = "qwen-1.5b-grpo"
    last_act_was_fallback = False
    def reset(self):
        self.last_act_was_fallback = False
    def act(self, obs):
        out = llm_act(obs)
        self.last_act_was_fallback = bool(getattr(llm_act, "_last_was_fallback", False))
        return out

trained_runs = {}
t0 = time.time()
for sid in TRAIN_SCENARIOS:
    runs = [run_episode(env, TrainedLLMPolicy(), seed=s, scenario_id=sid) for s in SEEDS_POST]
    trained_runs[sid] = runs
    agg = aggregate_results(runs)
    print(f"{sid:<32s}  trained-llm={agg['mean_return']:7.3f}  "
          f"std={float(np.std([r.cumulative_reward for r in runs])):.3f}  "
          f"mon_fb={agg.get('monitor_fallback_rate', 0):.3f}")
print(f"trained-policy eval (train scenarios) elapsed: {time.time()-t0:.1f}s")
# Out:
# supply_chain_token_drift          trained-llm=  5.515  std=1.004  mon_fb=0.000
# federated_identity_takeover       trained-llm=  1.139  std=2.580  mon_fb=0.000
# insider_repo_pivot                trained-llm=  5.310  std=0.991  mon_fb=0.000
# trained-policy eval (train scenarios) elapsed: 433.3s

# %% [markdown]
# ### 7a. Held-out OOD evaluation
#
# The whole point of holding out `cloud_metadata_ssrf` from training is
# this cell: a clean read on whether the trained policy *generalises* or
# just memorised per-scenario plans.

# %%
heldout_runs = {}
t0 = time.time()
for sid in HELDOUT_SCENARIOS:
    runs = [run_episode(env, TrainedLLMPolicy(), seed=s, scenario_id=sid) for s in SEEDS_POST]
    heldout_runs[sid] = runs
    agg = aggregate_results(runs)
    rand_mean = aggregate_results(baseline_runs[sid]['random'])['mean_return']
    heur_mean = aggregate_results(baseline_runs[sid]['heuristic'])['mean_return']
    std = float(np.std([r.cumulative_reward for r in runs]))
    print(f"{sid:<32s}  trained-llm={agg['mean_return']:7.3f}  std={std:.3f}  "
          f"vs heur={heur_mean:.3f}  vs rand={rand_mean:.3f}")
print(f"trained-policy eval (held-out scenarios) elapsed: {time.time()-t0:.1f}s")

heldout_metrics = {
    sid: {
        "random":      aggregate_results(baseline_runs[sid]["random"]),
        "heuristic":   aggregate_results(baseline_runs[sid]["heuristic"]),
        "trained_llm": aggregate_results(heldout_runs[sid]),
    }
    for sid in HELDOUT_SCENARIOS
}
HELDOUT_JSON.write_text(json.dumps(heldout_metrics, indent=2))
print("wrote", HELDOUT_JSON)
# Out:
# cloud_metadata_ssrf               trained-llm=  5.482  std=1.132  vs heur=3.048  vs rand=1.723
# trained-policy eval (held-out scenarios) elapsed: 98.6s
# wrote /content/cybersec_workdir/heldout_metrics.json

# %% [markdown]
# ### 7c. Full-horizon trace (trained LLM)
#
# Same table as §2c, but actions come from the **fine-tuned** policy (`TrainedLLMPolicy` + loaded adapter). Requires §7 cells to have run.

# %%
print("--- trained LLM full-episode trace ---")
_ = run_and_print_episode_trace(
    env, TrainedLLMPolicy(), seed=0, scenario_id=TRAIN_SCENARIOS[0], obs_preview=200
)
# Out:
# --- trained LLM full-episode trace ---
#  tick_after                                                                                action  step_reward  cumulative                                                                                                                                                                                      observation_preview
#           1 {'metadata': {}, 'action_type': 'ActionType.ISOLATE_ASSET', 'target': 'ci-runner-01'}        5.202       5.202 tick=0/70  scenario=supply_chain_token_drift  attacker=aggressive isolated_assets=[] revoked_identities=[] blocked_egress=[] patched=[] confirmed_compromised=[] valid_targets={'assets': ['ci-runner-01

# %% [markdown]
# ## 8. Before/after curves on identical axes

# %%
all_post = {**trained_runs, **heldout_runs}
panels = ALL_SCENARIOS
fig, axes = plt.subplots(1, len(panels), figsize=(5 * len(panels), 4), sharey=True)
if len(panels) == 1:
    axes = [axes]
for ax, sid in zip(axes, panels):
    cell = baseline_runs[sid]
    llm  = all_post.get(sid, [])
    base_ep = (base_runs or {}).get(sid, [])
    horizon = max(
        max(len(r.reward_curve) for r in cell['random']),
        max(len(r.reward_curve) for r in cell['heuristic']),
        max((len(r.reward_curve) for r in llm), default=1),
        max((len(r.reward_curve) for r in base_ep), default=1),
    )
    palette = [("random", cell['random'], "tab:gray"),
               ("heuristic", cell['heuristic'], "tab:blue"),
               ("base-llm", base_ep, "tab:green"),
               ("trained-llm", llm, "tab:red")]
    for label, runs, color in palette:
        if not runs:
            continue
        if label == "base-llm" and not base_runs:
            continue
        cumr = _padded_cumulative([r.reward_curve for r in runs], horizon)
        mean = cumr.mean(axis=0); std = cumr.std(axis=0)
        ax.plot(mean, label=label, color=color)
        ax.fill_between(np.arange(horizon), mean - std, mean + std, color=color, alpha=0.15)
    held_out_tag = "  (HELD-OUT)" if sid in HELDOUT_SCENARIOS else ""
    ax.set_title(sid + held_out_tag, fontsize=10); ax.set_xlabel("tick"); ax.axhline(0, color="k", lw=0.5)
axes[0].set_ylabel("cumulative reward"); axes[0].legend()
fig.suptitle(
    f"Cybersec OpenEnv -- pre/post GRPO ({MODE['grpo_max_steps_effective']} opt steps), "
    f"n={MODE['n_post_train_episodes']}/scenario"
)
fig.tight_layout(); fig.savefig(BEFORE_AFTER, dpi=140); plt.show()

# %% [markdown]
# ## 8b. Aggregate performance across all scenarios
#
# One line per policy, averaged across all training scenarios (left) and held-out (right).

# %%
AGG_GRAPH = ARTIFACTS / "aggregate_performance.png"

fig, axes = plt.subplots(1, 2, figsize=(12, 5), sharey=True)
scenario_groups = [
    ("Training Scenarios (Aggregate)", TRAIN_SCENARIOS),
    ("Held-out Scenario", HELDOUT_SCENARIOS),
]

policy_palette = [
    ("random",       lambda sid: baseline_runs[sid]["random"],       "#6b7280"),
    ("heuristic",    lambda sid: baseline_runs[sid]["heuristic"],    "#3b82f6"),
    ("base-llm",     lambda sid: (base_runs or {}).get(sid, []),      "#22c55e"),
    ("trained-llm",  lambda sid: all_post.get(sid, []),               "#ef4444"),
]

for ax, (panel_title, sids) in zip(axes, scenario_groups):
    if not sids:
        ax.set_visible(False)
        continue
    # Longest curve across all policies in this panel (random can be shorter than trained-llm).
    max_horizon = 1
    for s in sids:
        for _label, runs_fn, _color in policy_palette:
            runs = runs_fn(s)
            if not runs:
                continue
            max_horizon = max(max_horizon, max(len(r.reward_curve) for r in runs))
    for label, runs_fn, color in policy_palette:
        per_scenario_means = []
        for sid in sids:
            runs = runs_fn(sid)
            if not runs:
                continue
            cumr = _padded_cumulative([r.reward_curve for r in runs], max_horizon)
            per_scenario_means.append(cumr.mean(axis=0))
        if not per_scenario_means:
            continue
        grand_mean = np.mean(per_scenario_means, axis=0)
        grand_std = np.std(per_scenario_means, axis=0)
        ax.plot(grand_mean, label=label, color=color, linewidth=2)
        ax.fill_between(
            np.arange(len(grand_mean)),
            grand_mean - grand_std, grand_mean + grand_std,
            color=color, alpha=0.12,
        )
    ax.set_title(panel_title, fontsize=12, fontweight="bold")
    ax.set_xlabel("tick")
    ax.axhline(0, color="k", lw=0.5)
axes[0].set_ylabel("mean cumulative reward")
axes[0].legend(loc="upper left")
fig.suptitle(
    f"Cybersec OpenEnv -- Aggregate Before/After GRPO "
    f"({MODE['grpo_max_steps_effective']} opt steps)",
    fontsize=13, fontweight="bold",
)
fig.tight_layout()
fig.savefig(AGG_GRAPH, dpi=140)
plt.show()
print(f"saved {AGG_GRAPH}")
# Out:
# saved /content/cybersec_workdir/aggregate_performance.png

# %% [markdown]
# ## 9. Summary table + headline delta

# %%
rows = []
for sid in ALL_SCENARIOS:
    cell = baseline_runs[sid]
    post_runs = all_post.get(sid, [])
    br = (base_runs or {}).get(sid, [])
    policy_rows = [
        ("random",      cell["random"]),
        ("heuristic",   cell["heuristic"]),
        ("base-llm",    br),
        ("trained-llm", post_runs),
    ]
    for policy_name, runs in policy_rows:
        if not runs:
            continue
        agg = aggregate_results(runs)
        returns = [r.cumulative_reward for r in runs]
        rows.append({
            "scenario":     sid,
            "split":        "held-out" if sid in HELDOUT_SCENARIOS else "train",
            "policy":       policy_name,
            "mean_return":  agg["mean_return"],
            "std_return":   round(float(np.std(returns)), 3) if returns else 0.0,
            "mean_stages":  agg["mean_stages_succeeded"],
            "exfil_rate":   agg["exfil_rate"],
            "invalid_rate": agg["mean_invalid_actions"],
            "mon_fallback":  agg.get("monitor_fallback_rate", 0.0),
        })
df = pd.DataFrame(rows)
print(df.to_string(index=False))

post_metrics = {
    sid: {
        "random":      aggregate_results(baseline_runs[sid]["random"]),
        "heuristic":   aggregate_results(baseline_runs[sid]["heuristic"]),
        "base_llm":     aggregate_results((base_runs or {}).get(sid, [])) if (base_runs or {}).get(sid) else None,
        "trained_llm": aggregate_results(all_post.get(sid, [])) if all_post.get(sid) else None,
    }
    for sid in ALL_SCENARIOS
}
post_metrics["_meta"] = {
    "n_post_episodes": MODE["n_post_train_episodes"],
    "grpo_max_steps_effective": MODE["grpo_max_steps_effective"],
    "grpo_steps_per_outer_loop": MODE["grpo_steps_per_outer_loop"],
    "on_policy_outer_loops": MODE["on_policy_outer_loops"],
    "grpo_num_train_epochs": MODE.get("grpo_num_train_epochs", 1),
    "grpo_precision":    "fp16" if torch.cuda.is_available() else "fp32",
    "run_manifest":    str(RUN_MANIFEST),
    "model":           MODEL_NAME,
    "adapter":         str(ADAPTER_DIR),
    "run_base_llm_eval": bool(MODE.get("run_base_llm_eval", True)),
    "train_scenarios": TRAIN_SCENARIOS,
    "heldout_scenarios": HELDOUT_SCENARIOS,
    "reward_funcs":    REWARD_NAMES,
}
POST_JSON.write_text(json.dumps(post_metrics, indent=2))
SUMMARY_MD.write_text(df.to_markdown(index=False))
print("wrote", POST_JSON)
print("wrote", SUMMARY_MD)
# Out:
#                    scenario    split      policy  mean_return  std_return  mean_stages  exfil_rate  invalid_rate  mon_fallback
#    supply_chain_token_drift    train      random        2.156       3.385        1.000       0.000         0.000         0.000
#    supply_chain_token_drift    train   heuristic        2.872       3.528        1.767       0.100         0.000         0.000
#    supply_chain_token_drift    train    base-llm        5.832       0.791        0.000       0.000         0.467         0.204
#    supply_chain_token_drift    train trained-llm        5.515       1.004        0.033       0.000         0.033         0.000
# federated_identity_takeover    train      random        0.198       3.939        1.100       0.000         0.000         0.000
# federated_identity_takeover    train   heuristic        2.985       2.618        1.200       0.033         0.000         0.000
# federated_identity_takeover    train    base-llm        1.498       0.924        0.867       0.000         0.733         0.111
# federated_identity_takeover    train trained-llm        1.139       2.580        0.900       0.000         0.167         0.000
#          insider_repo_pivot    train      random        2.905       3.640        0.933       0.000         0.000         0.000
#          insider_repo_pivot    train   heuristic        3.057       2.465        1.700       0.033         0.000         0.000
#          insider_repo_pivot    train    base-llm        4.627       2.130        0.333       0.000         0.400         0.105
#          insider_repo_pivot    train trained-llm        5.310       0.991        0.100       0.000         0.000         0.000
#         cloud_metadata_ssrf held-out      random        1.723       2.615        1.200       0.000         0.000         0.000
#         cloud_metadata_ssrf held-out   heuristic        3.048       1.684        1.700       0.000         0.000         0.000
#         cloud_metadata_ssrf held-out    base-llm        4.912       1.575        0.133       0.000         0.267         0.133
#         cloud_metadata_ssrf held-out trained-llm        5.482       1.132        0.067       0.000         0.000         0.000
# wrote /content/cybersec_workdir/post_train_metrics.json
# wrote /content/cybersec_workdir/summary_table.md

# %%
print("=== Headline delta (trained-llm vs heuristic) ===")
for sid in ALL_SCENARIOS:
    h = aggregate_results(baseline_runs[sid]["heuristic"])["mean_return"]
    runs = all_post.get(sid, [])
    if not runs:
        continue
    t = aggregate_results(runs)["mean_return"]
    tag = "(HELD-OUT)" if sid in HELDOUT_SCENARIOS else "(train)"
    print(f"{sid:<32s} {tag:<11s} heuristic={h:7.3f}  trained-llm={t:7.3f}  delta={t-h:+.3f}")
# Out:
# === Headline delta (trained-llm vs heuristic) ===
# supply_chain_token_drift         (train)     heuristic=  2.872  trained-llm=  5.515  delta=+2.643
# federated_identity_takeover      (train)     heuristic=  2.985  trained-llm=  1.139  delta=-1.846
# insider_repo_pivot               (train)     heuristic=  3.057  trained-llm=  5.310  delta=+2.253
# cloud_metadata_ssrf              (HELD-OUT)  heuristic=  3.048  trained-llm=  5.482  delta=+2.434

# %% [markdown]
# ## 10. Sanity assertions (strict canaries)
#
# When `MODE["strict_canary"]` is **True** (recommended for submission runs), this
# cell **asserts** on: aggregate heuristic-vs-random, valid-action rate,
# train-vs-random floor, **≥2/3 training scenarios** with `std_return > 0.1`
# (anti-collapse), and a cap on **MONITOR parse-fallback** rate.
# Set `strict_canary: False` in `MODE` only for local experimentation when you need prints without asserts.

# %%
# 1. Reward shaping is healthy: heuristic must out-earn random *on aggregate*.
_sc = MODE.get("strict_canary", True)
heur_total = sum(
    float(np.mean([r.cumulative_reward for r in cell['heuristic']]))
    for cell in baseline_runs.values()
)
rand_total = sum(
    float(np.mean([r.cumulative_reward for r in cell['random']]))
    for cell in baseline_runs.values()
)
print(f"baseline totals: heuristic={heur_total:+.3f}  random={rand_total:+.3f}")
if _sc:
    assert heur_total > rand_total, (
        f"reward shaping regressed: heuristic total ({heur_total:.3f}) "
        f"<= random total ({rand_total:.3f}) summed across scenarios"
    )

# 2. Trained policy must produce mostly-valid actions across all trained
#    episodes. Aggregate over train + held-out to keep one number.
total_steps = sum(len(r.reward_curve) for runs in all_post.values() for r in runs)
total_invalid = sum(r.invalid_action_count for runs in all_post.values() for r in runs)
valid_rate = 1.0 - (total_invalid / max(1, total_steps))
print(f"valid-action rate across all post-train episodes: {valid_rate:.1%}  "
      f"({total_invalid} invalid / {total_steps} steps)")
if _sc:
    assert valid_rate >= 0.8, (
        f"trained policy is producing too many invalid actions ({valid_rate:.1%} valid)"
    )

# 3. Trained policy must not be catastrophically worse than random on any
#    *training* scenario. (Held-out scenarios are allowed to be worse --
#    that's the point of generalisation reporting; we just print it.)
for sid in TRAIN_SCENARIOS:
    rand = float(np.mean([r.cumulative_reward for r in baseline_runs[sid]['random']]))
    llm  = float(np.mean([r.cumulative_reward for r in trained_runs[sid]]))
    if _sc:
        assert llm >= rand - 5.0, (
            f"{sid}: trained-llm ({llm:.3f}) is more than 5 points below random "
            f"({rand:.3f}) -- training likely diverged"
        )

# 4. Strict reward-hack canary: std_return > 0.1 on at least (n_train - 1)
#    i.e. 2 of 3 training scenarios — catches iter-3/4 single-scenario variance.
non_zero_std_scenarios = []
for sid in TRAIN_SCENARIOS:
    returns = [r.cumulative_reward for r in trained_runs[sid]]
    s = float(np.std(returns))
    print(f"{sid:<32s}  trained-llm std_return={s:.4f}")
    if s > 0.1:
        non_zero_std_scenarios.append(sid)
_required = max(2, len(TRAIN_SCENARIOS) - 1)
if _sc:
    assert len(non_zero_std_scenarios) >= _required, (
        f"REWARD HACK CANARY: trained-llm has std_return < 0.1 on "
        f"{len(TRAIN_SCENARIOS) - len(non_zero_std_scenarios)} of {len(TRAIN_SCENARIOS)} "
        f"training scenarios (non-zero: {non_zero_std_scenarios}). "
        f"Try raising grpo_num_generations / grpo_temperature, grpo_beta, or grpo_steps_per_outer_loop."
    )

# 5. Parse / MONITOR fallback must stay bounded (unparseable JSON -> MONITOR).
total_fb = sum(r.monitor_fallback_count for runs in all_post.values() for r in runs)
fb_rate = total_fb / max(1, total_steps)
print(f"monitor_fallback rate (trained): {fb_rate:.1%}")
if _sc:
    assert fb_rate <= 0.5, (
        f"trained-llm falls back to MONITOR on {fb_rate:.1%} of steps — check completions"
    )

print("all sanity checks passed" if _sc else "strict_canary=False: diagnostics only (asserts skipped)")
# Out:
# baseline totals: heuristic=+11.963  random=+6.981
# valid-action rate across all post-train episodes: 98.3%  (6 invalid / 343 steps)
# supply_chain_token_drift          trained-llm std_return=1.0035
# federated_identity_takeover       trained-llm std_return=2.5796
# insider_repo_pivot                trained-llm std_return=0.9907
# monitor_fallback rate (trained): 0.0%
# all sanity checks passed

# %% [markdown]
# ## 11. (Optional) Push artifacts back to the HF Space
#
# If you want the trained adapter and updated metrics to live on the HF
# Space alongside the env (so the judges can diff `_artifacts/` between
# iter-1 and iter-2), enable this cell. It uses the same
# `huggingface_hub` API as the install cell.

# %%
# Set this to True after a successful run if you want to upload artifacts.
PUSH_ARTIFACTS = False

if PUSH_ARTIFACTS:
    from huggingface_hub import HfApi
    api = HfApi()
    api.upload_folder(
        folder_path=str(ARTIFACTS),
        path_in_repo="_artifacts",
        repo_id=HF_SPACE_REPO_ID,
        repo_type="space",
        commit_message="training artifacts",
    )
    print("uploaded _artifacts/ to", HF_SPACE_REPO_ID)
else:
    print("artifact push skipped (set PUSH_ARTIFACTS=True to enable)")
# Out:
# artifact push skipped (set PUSH_ARTIFACTS=True to enable)
